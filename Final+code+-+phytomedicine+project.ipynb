# %% [markdown]
# # Pytomedicine Project

# %% [markdown]
# Building the undirected weighted graph

# %%
# import libraries
import pandas as pd
import numpy as np
from pandas import DataFrame
import matplotlib
import matplotlib.pyplot as plt
from heapq import heappush, heappop 
from itertools import count
import networkx as nx 
import random
import warnings 
from networkx.drawing.nx_agraph import graphviz_layout
warnings.filterwarnings("ignore")
import importlib
from scipy.sparse import csr_matrix
from scipy.sparse.csgraph import minimum_spanning_tree
import Networks_functions as nf
from tkinter import *
from networkx.algorithms import tree
from collections import Counter
import networkx as nx
from pandas import ExcelWriter
from pandas import ExcelFile
import matplotlib.patches as mpatches
import seaborn as sns; sns.set()

# %%
importlib.reload(nf)
# Out:
# <module 'Networks_functions' from '/Users/majabratovic/Networks_functions.py'>

# %%
# code pre each protein
# 1) NP_004574 (dowm regulated)
# upload the data and make a proper DataFrame
data1 = pd.read_csv('proteins_1_homo.csv',delimiter=",")
genmatrix1= DataFrame(data1)
genode1=DataFrame(data1,columns=['Official Symbol Interactor A', 'Official Symbol Interactor B'])

# %%
# create a tulpe from a list to use it as nodes in network construction
my_list1 = list(genmatrix1["Official Symbol Interactor A"].values)
my_list2 = list(genmatrix1["Official Symbol Interactor B"].values)
my_list_1=my_list1+my_list2
my_tuple_1=tuple(my_list_1)

# %%
# calculate wight based on # of interactions
weight_node_1=Counter(my_list_1)

# %%
# create a list with edges
list1=list(weight_node_1.keys())
list2=list(weight_node_1.values())

# %%
# create a graph
G1=nx.Graph()

# %%
# add nodes
G1.add_node(my_tuple_1)

# %%
# add edges
G1.add_edge('NP_004574', list1[0], weight= list2[0])

for value in range(0,len(list1)):
   variable = G1.add_edge('NP_004574', list1[value], weight= list2[value])

# %%
# add additional nodes gto build a whole network
# 2) EAW53700 (dowm regulated)
data2 = pd.read_csv('proteins_2_homo.csv')
genmatrix2= DataFrame(data2)
genode2=DataFrame(data2,columns=['Official Symbol Interactor A', 'Official Symbol Interactor B'])

my_list3 = list(genmatrix2["Official Symbol Interactor A"].values)
my_list4 = list(genmatrix2["Official Symbol Interactor B"].values)

my_list_2=my_list3+my_list4
my_tuple_2=tuple(my_list_2)

from collections import Counter
weight_node_2=Counter(my_list_2)

list3=list(weight_node_2.keys())
list4=list(weight_node_2.values())

import networkx as nx
G2=nx.Graph()
G2.add_node(my_tuple_2)

G2.add_edge('EAW53700', list3[0], weight= list4[0])

for value in range(0,len(list3)):
   variable = G2.add_edge('EAW53700', list3[value], weight= list4[value])

# %%
# create a network netween two molecus and color the nodes with the degree >1 in blue
# create a graph
U_two_nodes=nx.Graph()
U_two_nodes.add_edges_from(G1.edges()+G2.edges())
U_two_nodes.add_nodes_from(G1.nodes()+G2.nodes())

# find the degree
info=U.degree(nbunch=None, weight=None)
DataFrame(info, index=[0])

# select overlap i.e. nodes with degree >1
overlap_nodes=list(k for k, v in info.items() if v > 1)

# build two molecules network, and select nodes with the degree <1
single_nodes=list(k for k, v in info.items() if v <= 1)

#create a graph
fig = plt.figure()
nx.draw(U, with_labels=True, nodelist=overlap_nodes,node_color='b', font_size=6)
plt.show()

# %%
#  diffrent visualisation of the two molecule network
layout = nx.spring_layout(U_two_nodes,iterations=1000)
nx.draw_networkx_nodes(U_two_nodes, layout, nodelist=overlap_nodes, node_color='b', node_size=len(a))
nx.draw_networkx_nodes(U_two_nodes, layout, nodelist=single_nodes, node_color='r', node_size=len(b))
nx.draw_networkx_edges(U_two_nodes, layout, width=0.5, dge_color="ccccc")
plt.show()

# %%
#3) CAG46507 (dowm regulated)
data3 = pd.read_csv('proteins_3_homo.csv',delimiter=",")
genmatrix3= DataFrame(data3)
genode3=DataFrame(data3,columns=['Official Symbol Interactor A', 'Official Symbol Interactor B'])

my_list5 = list(genmatrix3["Official Symbol Interactor A"].values)
my_list6 = list(genmatrix3["Official Symbol Interactor B"].values)
my_list_3=my_list5+my_list6
my_tuple_3=tuple(my_list_3)

from collections import Counter
weight_node_3=Counter(my_list_3)
weight_node_3

list5=list(weight_node_3.keys())
list6=list(weight_node_3.values())

import networkx as nx
G3=nx.Graph()
G3.add_node(my_tuple_3)

G3.add_edge('CAG46507', list5[0], weight= list6[0])

for value in range(0,len(list5)):
   variable = G3.add_edge('CAG46507', list5[value], weight= list6[value])

# %%
# 4) EAW98517 (dowm regulated)
data4 = pd.read_csv('proteins_4_homo.csv',delimiter=",")
genmatrix4= DataFrame(data4)
genode4=DataFrame(data4,columns=['Official Symbol Interactor A', 'Official Symbol Interactor B'])

my_list7 = list(genmatrix4["Official Symbol Interactor A"].values)
my_list8 = list(genmatrix4["Official Symbol Interactor B"].values)
my_list_4=my_list7+my_list8
my_tuple_4=tuple(my_list_4)

from collections import Counter
weight_node_4=Counter(my_list_4)
weight_node_4

list7=list(weight_node_4.keys())
list8=list(weight_node_4.values())

import networkx as nx
G4=nx.Graph()
G4.add_node(my_tuple_4)
G4.add_edge('EAW98517', list7[0], weight= list8[0])

for value in range(0,len(list7)):
   variable = G4.add_edge('EAW98517', list7[value], weight= list8[value])

# %%
# 5) NP_006588 (up reguated)
data5 = pd.read_csv('proteins_5_homo.csv',delimiter=",")
genmatrix5= DataFrame(data5)
genode5=DataFrame(data5,columns=['Official Symbol Interactor A', 'Official Symbol Interactor B'])

my_list9 = list(genmatrix5["Official Symbol Interactor A"].values)
my_list10 = list(genmatrix5["Official Symbol Interactor B"].values)
my_list_5=my_list9+my_list10
my_tuple_5=tuple(my_list_5)

from collections import Counter
weight_node_5=Counter(my_list_5)
weight_node_5

list9=list(weight_node_5.keys())
list10=list(weight_node_5.values())

import networkx as nx
G5=nx.Graph()
G5.add_node(my_tuple_5)

G5.add_edge('NP_006588', list9[0], weight= list10[0])

for value in range(0,len(list9)):
   variable = G5.add_edge('NP_006588', list9[value], weight= list10[value])

# %%
# 6) ABB01006 (up reguated)
data6 = pd.read_csv('proteins_6_homo.csv',delimiter=",")
genmatrix6= DataFrame(data6)
genode6=DataFrame(data6,columns=['Official Symbol Interactor A', 'Official Symbol Interactor B'])

my_list11 = list(genmatrix6["Official Symbol Interactor A"].values)
my_list12 = list(genmatrix6["Official Symbol Interactor B"].values)
my_list_6=my_list11+my_list12
my_tuple_6=tuple(my_list_6)

from collections import Counter
weight_node_6=Counter(my_list_6)

list11=list(weight_node_6.keys())
list12=list(weight_node_6.values())

import networkx as nx
G6=nx.Graph()
G6.add_node(my_tuple_6)

G6.add_edge('ABB01006', list11[0], weight= list12[0])

for value in range(0,len(list11)):
   variable = G6.add_edge('ABB01006', list11[value], weight= list12[value])

# %%
# 7) CAI64497 (up reguated)
data7 = pd.read_csv('proteins_7_homo.csv',delimiter=",")
genmatrix7= DataFrame(data7)
genode7=DataFrame(data7,columns=['Official Symbol Interactor A', 'Official Symbol Interactor B'])

my_list13 = list(genmatrix7["Official Symbol Interactor A"].values)
my_list14 = list(genmatrix7["Official Symbol Interactor B"].values)
my_list_7=my_list13+my_list14
my_tuple_7=tuple(my_list_7)

from collections import Counter
weight_node_7=Counter(my_list_7)

list13=list(weight_node_7.keys())
list14=list(weight_node_7.values())

import networkx as nx
G7=nx.Graph()
G7.add_node(my_tuple_7)

G7.add_edge('CAI64497', list13[0], weight= list14[0])

for value in range(0,len(list13)):
   variable = G7.add_edge('CAI64497', list13[value], weight= list14[value])

# %%
# 8) NP_005339 (up reguated)

data8 = pd.read_csv('proteins_8_homo.csv',delimiter=",")
genmatrix8= DataFrame(data8)
genode8=DataFrame(data8,columns=['Official Symbol Interactor A', 'Official Symbol Interactor B'])

my_list13 = list(genmatrix8["Official Symbol Interactor A"].values)
my_list14 = list(genmatrix8["Official Symbol Interactor B"].values)
my_list_8=my_list13+my_list14
my_tuple_8=tuple(my_list_8)

from collections import Counter
weight_node_8=Counter(my_list_8)

list13=list(weight_node_8.keys())
list14=list(weight_node_8.values())

import networkx as nx
G8=nx.Graph()
G8.add_node(my_tuple_8)

G8.add_edge('NP_005339', list13[0], weight= list14[0])

for value in range(0,len(list13)):
   variable = G8.add_edge('NP_005339', list13[value], weight= list14[value])

# %%
# 9) P43358 (up reguated)

data9 = pd.read_csv('proteins_9_homo.csv',delimiter=",")
genmatrix9= DataFrame(data9)
genode9=DataFrame(data9,columns=['Official Symbol Interactor A', 'Official Symbol Interactor B'])

my_list15 = list(genmatrix9["Official Symbol Interactor A"].values)
my_list16 = list(genmatrix9["Official Symbol Interactor B"].values)
my_list_9=my_list15+my_list16
my_tuple_9=tuple(my_list_9)

from collections import Counter
weight_node_9=Counter(my_list_9)

list15=list(weight_node_9.keys())
list16=list(weight_node_9.values())

import networkx as nx
G9=nx.Graph()
G9.add_node(my_tuple_9)

G9.add_edge('P43358', list15[0], weight= list16[0])

for value in range(0,len(list15)):
   variable = G9.add_edge('P43358', list15[value], weight= list16[value])

# %%
# 10) NP_037473 (up reguated)

data10 = pd.read_csv('proteins_10_homo.csv',delimiter=",")
genmatrix10= DataFrame(data10)
genode10=DataFrame(data10,columns=['Official Symbol Interactor A', 'Official Symbol Interactor B'])

my_list17 = list(genmatrix10["Official Symbol Interactor A"].values)
my_list18 = list(genmatrix10["Official Symbol Interactor B"].values)
my_list_10=my_list17+my_list18
my_tuple_10=tuple(my_list_10)

from collections import Counter
weight_node_10=Counter(my_list_10)

list17=list(weight_node_10.keys())
list18=list(weight_node_10.values())

import networkx as nx
G10=nx.Graph()
G10.add_node(my_tuple_10)

G10.add_edge('NP_037473', list17[0], weight= list18[0])

for value in range(0,len(list17)):
   variable = G10.add_edge('NP_037473', list17[value], weight= list18[value])

# %%
# 11) EAW86495 (up reguated)

data11 = pd.read_csv('proteins_11_homo.csv',delimiter=",")
genmatrix11= DataFrame(data11)
genode11=DataFrame(data11,columns=['Official Symbol Interactor A', 'Official Symbol Interactor B'])

my_list19 = list(genmatrix11["Official Symbol Interactor A"].values)
my_list20 = list(genmatrix11["Official Symbol Interactor B"].values)
my_list_11=my_list19+my_list20
my_tuple_11=tuple(my_list_11)

from collections import Counter
weight_node_11=Counter(my_list_11)

list19=list(weight_node_11.keys())
list20=list(weight_node_11.values())

import networkx as nx
G11=nx.Graph()
G11.add_node(my_tuple_11)

G11.add_edge('EAW86495', list19[0], weight= list20[0])

for value in range(0,len(list19)):
   variable = G11.add_edge('EAW86495', list19[value], weight= list20[value])

# %%
# 12) AAH51814 (up reguated)

data12 = pd.read_csv('proteins_12_homo.csv',delimiter=",")
genmatrix12= DataFrame(data12)
genode12=DataFrame(data11,columns=['Official Symbol Interactor A', 'Official Symbol Interactor B'])

my_list21 = list(genmatrix12["Official Symbol Interactor A"].values)
my_list22 = list(genmatrix12["Official Symbol Interactor B"].values)
my_list_12=my_list21+my_list22
my_tuple_12=tuple(my_list_12)

from collections import Counter
weight_node_12=Counter(my_list_12)

list21=list(weight_node_12.keys())
list22=list(weight_node_12.values())

import networkx as nx
G12=nx.Graph()
G12.add_node(my_tuple_12)

G12.add_edge('AAH51814', list21[0], weight= list22[0])

for value in range(0,len(list21)):
   variable = G12.add_edge('AAH51814', list21[value], weight= list22[value])

# %%
# 13) NP_001737 (up reguated)

data13 = pd.read_csv('proteins_13_homo.csv',delimiter=",")
genmatrix13= DataFrame(data13)
genode13=DataFrame(data13,columns=['Official Symbol Interactor A', 'Official Symbol Interactor B'])

my_list23 = list(genmatrix13["Official Symbol Interactor A"].values)
my_list24 = list(genmatrix13["Official Symbol Interactor B"].values)
my_list_13=my_list23+my_list24
my_tuple_13=tuple(my_list_13)

from collections import Counter
weight_node_13=Counter(my_list_13)

list21=list(weight_node_13.keys())
list22=list(weight_node_13.values())

import networkx as nx
G13=nx.Graph()
G13.add_node(my_tuple_13)

G13.add_edge('NP_001737', list21[0], weight= list22[0])

for value in range(0,len(list21)):
   variable = G13.add_edge('NP_001737', list21[value], weight= list22[value])

# %%
# 14) AAW67757 (up reguated)

data14 = pd.read_csv('proteins_14_homo.csv',delimiter=",")
genmatrix14= DataFrame(data14)
genode14=DataFrame(data14,columns=['Official Symbol Interactor A', 'Official Symbol Interactor B'])

my_list25 = list(genmatrix13["Official Symbol Interactor A"].values)
my_list26 = list(genmatrix13["Official Symbol Interactor B"].values)
my_list_14=my_list25+my_list26
my_tuple_14=tuple(my_list_14)

from collections import Counter
weight_node_14=Counter(my_list_14)

list25=list(weight_node_14.keys())
list26=list(weight_node_14.values())

import networkx as nx
G14=nx.Graph()
G14.add_node(my_tuple_14)

G14.add_edge('AAW67757', list25[0], weight= list26[0])

for value in range(0,len(list25)):
   variable = G14.add_edge('AAW67757', list25[value], weight= list26[value])

# %%
# 15) NP_006380 (up reguated)

data15 = pd.read_csv('proteins_15_homo.csv',delimiter=",")
genmatrix15= DataFrame(data15)
genode15=DataFrame(data15,columns=['Official Symbol Interactor A', 'Official Symbol Interactor B'])

my_list27 = list(genmatrix15["Official Symbol Interactor A"].values)
my_list28 = list(genmatrix15["Official Symbol Interactor B"].values)
my_list_15=my_list27+my_list28
my_tuple_15=tuple(my_list_15)

from collections import Counter
weight_node_15=Counter(my_list_15)

list27=list(weight_node_15.keys())
list28=list(weight_node_15.values())

import networkx as nx
G15=nx.Graph()
G15.add_node(my_tuple_15)

G15.add_edge('NP_006380', list27[0], weight= list28[0])

for value in range(0,len(list27)):
   variable = G15.add_edge('NP_006380', list27[value], weight= list28[value])

# %%
# 16) BAD93042 (up reguated)

data16 = pd.read_csv('proteins_16_homo.csv',delimiter=",")
genmatrix16= DataFrame(data16)
genode16=DataFrame(data16,columns=['Official Symbol Interactor A', 'Official Symbol Interactor B'])

my_list29 = list(genmatrix16["Official Symbol Interactor A"].values)
my_list30 = list(genmatrix16["Official Symbol Interactor B"].values)
my_list_16=my_list29+my_list30
my_tuple_16=tuple(my_list_16)

from collections import Counter
weight_node_16=Counter(my_list_16)

list29=list(weight_node_16.keys())
list30=list(weight_node_16.values())

import networkx as nx
G16=nx.Graph()
G16.add_node(my_tuple_16)

G16.add_edge('BAD93042', list29[0], weight= list30[0])

for value in range(0,len(list29)):
   variable = G16.add_edge('BAD93042', list29[value], weight= list30[value])

# %% [markdown]
# Network with all 16 proteins

# %%
# Final graph
# all 16 proteins together (diffrent way)
U=nx.Graph()
U.add_edges_from(G1.edges()+G2.edges()+G3.edges()+G4.edges()+G5.edges()+G6.edges()+G7.edges()+G8.edges()+G9.edges()+G10.edges()+G11.edges()+G12.edges()+G13.edges()+G14.edges()+G15.edges()+G16.edges())
# U.add_nodes_from(U.nodes()+g.nodes())
nx.draw(U)
plt.show()

# %%
# . save it as U_whole
U_whole=U.copy()

# %% [markdown]
# Descriptive Statisctics

# %%
# no of nodes
list_nodes = pd.DataFrame(U_whole.nodes())
list_nodes.to_csv('list_edges.csv')
len(list_nodes)
# Out:
# 2332

# %%
# no. of edges
list_edges = pd.DataFrame(U_whole.edges())
list_edges.to_csv('list_edges.csv')
len(list_edges)
# Out:
# 3527

# %%
# sort nodes for the higest degree
a1=nx.degree(U_whole)
a1_sorted= sorted(a1,key=a1.get, reverse=True)

for r in a1_sorted:
     print(r,a1[r])
# Out:
# NP_005339 817
# NP_006588 522
# AAH51814 387
# ABB01006 305
# NP_001737 232
# AAW67757 232
# CAI64497 169
# CAG46507 157
# NP_004574 156
# EAW98517 153
# BAD93042 136
# EAW86495 80
# NP_006380 75
# NP_037473 55
# P43358 32
# EAW53700 19
# NTRK1 14
# CUL7 12
# FBXO6 11
# FN1 10
# CUL3 10
# CDK2 9
# CDC73 9
# HDAC5 9
# VCP 9
# U2AF2 9
# STAU1 8
# CCDC8 8
# APP 8
# HUWE1 8
# FUS 8
# EGFR 8
# VCAM1 7
# ITGA4 7
# NXF1 7
# DLST 7
# VDAC1 7
# CDH1 7
# CDC5L 7
# MCM2 7
# SNW1 7
# DLD 6
# UQCRC2 6
# SOAT1 6
# ATF2 6
# UBL4A 6
# env 6
# ADRB2 6
# OBSL1 6
# ESRRB 6
# CYLD 6
# ESR1 6
# CFTR 6
# COPS5 6
# CAND1 6
# HSPA5 6
# HNRNPA1 6
# GBA 6
# RFWD3 6
# SLC9A1 6
# RAB1B 5
# TP53 5
# RAF1 5
# RNF2 5
# UBC 5
# AI837181 5
# EED 5
# DDOST 5
# LMAN1 5
# Mapk13 5
# ABL1 5
# BRCA1 5
# DNAJA1 5
# MDM2 5
# CUL2 5
# CUL1 5
# HDAC6 5
# TUBG1 5
# PDIA3 5
# GAPDH 5
# GANAB 5
# CLU 5
# H2AFX 5
# EWSR1 5
# RPA1 4
# RPA2 4
# RPA3 4
# MOV10 4
# ATL3 4
# Ksr1 4
# RAB1A 4
# RAB2A 4
# RPN1 4
# PHB 4
# CD4 4
# XPO1 4
# TRAF3IP1 4
# C1QBP 4
# SUZ12 4
# CLTC 4
# COX2 4
# Bmpr1a 4
# RPL7 4
# HSP90AB1 4
# BCAP31 4
# RAD21 4
# ISG15 4
# PAN2 4
# ILK 4
# CRY2 4
# IPO9 4
# KPNA4 4
# HSPA8 4
# BAG3 4
# STUB1 4
# PARK2 4
# SOD1 4
# HSP90AA1 4
# PSMA3 4
# PARD3 4
# CUL4A 4
# CUL5 4
# NEDD8 4
# PPP2R1A 4
# EEF1A1 4
# HSPA4 4
# LRRK2 4
# GRB2 4
# KCNH2 4
# RAD52 4
# WWOX 4
# LGALS3BP 4
# HSPB1 4
# GAN 4
# ERBB3 4
# DERL1 4
# TUBB 4
# AMFR 4
# CANX 4
# TCTN2 4
# TCTN3 4
# TCTN1 4
# Itgb1 4
# PTPRN 4
# COX15 4
# SDHA 4
# CSNK2A1 4
# EPRS 4
# SIRT7 4
# PTPRO 4
# ARRB2 3
# RAB7A 3
# GOLT1B 3
# ETFA 3
# PSMC2 3
# SMARCA4 3
# VDAC2 3
# FAF2 3
# CHMP4B 3
# SIN3A 3
# RB1 3
# MGMT 3
# YWHAE 3
# YWHAZ 3
# CYC1 3
# HSD17B10 3
# OLA1 3
# YIPF3 3
# AR 3
# RPS4X 3
# NPM1 3
# PRKCD 3
# NR3C1 3
# ELAVL1 3
# BCAR1 3
# rev 3
# PPME1 3
# KIF1C 3
# KPNA2 3
# FANCC 3
# DNAJC3 3
# MST1R 3
# CDK11B 3
# CDK4 3
# EBNA-LP 3
# SF3A2 3
# ARRB1 3
# FBXO25 3
# CUL4B 3
# COPS6 3
# AKT1 3
# EEF2 3
# HSPA1A 3
# KCNQ4 3
# BRAF 3
# IQCB1 3
# METTL21B 3
# STIP1 3
# AURKA 3
# CEP250 3
# RPS6KB2 3
# AMBRA1 3
# C12orf10 3
# HSPA9 3
# TECR 3
# PTEN 3
# AHSA1 3
# DNAJC7 3
# SKI 3
# CDKN1B 3
# PTGIR 3
# FAM187B 3
# BCR 3
# DNAJC9 3
# TUBA1A 3
# DNAJB4 3
# DNAJC2 3
# SERPINA1 3
# WNK1 3
# FANCA 3
# CDK9 3
# ALDOA 3
# BARD1 3
# NOS2 3
# LGR4 3
# UNK 3
# P4HB 3
# ITGB1 3
# TUBB4B 3
# HSP90B1 3
# APOB 3
# TERF1 3
# CALR 3
# LDLR 3
# MAPK7 3
# ERLIN2 3
# ARAF 3
# CCT3 3
# KPNA3 3
# RCN1 3
# RPN2 3
# SLC25A3 3
# SLC33A1 3
# SENP3 3
# GABRA1 3
# PRKCSH 3
# ACADM 3
# NDRG1 3
# SNRPE 3
# GRK5 3
# TUFM 3
# ATXN3 3
# PRMT5 3
# PKM 3
# SPTAN1 3
# UBXN6 3
# SOX2 3
# MTNR1A 3
# COPB1 3
# PTPRA 3
# RAB5C 2
# Rab5c 2
# HNRNPH1 2
# RAB11A 2
# VAPA 2
# RAB5A 2
# PTPN1 2
# PDHA1 2
# RBSN 2
# LDHA 2
# LDHB 2
# ATP6V1A 2
# ATP6V1B2 2
# CAV1 2
# COX6B1 2
# NDUFA7 2
# RAD51 2
# SMARCC1 2
# NOS1AP 2
# PHB2 2
# STOML2 2
# RMDN3 2
# BBX 2
# YIPF5 2
# PTRF 2
# LNX1 2
# GNAI2 2
# HDAC1 2
# NCOR1 2
# SMARCA2 2
# MYOD1 2
# tat 2
# ICT1 2
# SKP2 2
# EPAS1 2
# KRAS 2
# SPRTN 2
# RIC3 2
# ATP5B 2
# HSD17B12 2
# TMPO 2
# Lima1 2
# ZNF746 2
# ACTN1 2
# SLC25A5 2
# YWHAB 2
# IPO11 2
# CAPZA1 2
# GTF3C1 2
# SSR3 2
# NEK9 2
# PAK4 2
# Ranbp2 2
# HDGF 2
# EIF4A3 2
# MAGOH 2
# ASB2 2
# IKBKB 2
# TYK2 2
# IPO7 2
# BIRC5 2
# ACTG1 2
# PSMB5 2
# HIST1H3E 2
# PAX6 2
# CEP170P1 2
# RC3H1 2
# KIAA1377 2
# XRCC1 2
# TRA2B 2
# SON 2
# HERC5 2
# PPID 2
# HCFC1 2
# P2rx7 2
# DNAJA3 2
# JAK2 2
# DNAJB1 2
# BAG2 2
# BAG4 2
# TNFRSF1A 2
# HSF1 2
# HGS 2
# MAPT 2
# RPAP1 2
# PACSIN2 2
# PACSIN3 2
# RFWD2 2
# TSSK6 2
# HIST3H3 2
# FGFR3 2
# ERG 2
# USP50 2
# AGO4 2
# DYRK2 2
# UBE3A 2
# YWHAQ 2
# HLA-DRA 2
# HLA-DRB1 2
# HLA-DRB3 2
# HLA-DRB4 2
# HLA-DRB5 2
# MAPK8 2
# VHL 2
# MKKS 2
# UCHL1 2
# SNCA 2
# DCUN1D1 2
# MCL1 2
# SGTA 2
# AIPL1 2
# CBL 2
# UBASH3B 2
# SHC1 2
# IRAK1 2
# GCH1 2
# HSPD1 2
# HSPA2 2
# SMURF1 2
# CTNNB1 2
# SUGT1 2
# ESR2 2
# CCAR2 2
# MAP2K1 2
# PPP5C 2
# SYNPO2 2
# CAMKMT 2
# METTL20 2
# METTL22 2
# SLC12A3 2
# ST13 2
# HIF1A 2
# JUN 2
# TARDBP 2
# CDKN2A 2
# HSPA6 2
# RPS6KA3 2
# ERRFI1 2
# CDC20 2
# CDKN1A 2
# TUBGCP3 2
# MCF2 2
# LRRC28 2
# TSSK1B 2
# CCDC117 2
# DNAJA2 2
# DNAJB11 2
# RPLP0 2
# NPHP4 2
# Bag2 2
# MCM5 2
# KCNA5 2
# CDC37 2
# NFATC2 2
# HYPK 2
# KLHL34 2
# SF3A1 2
# ALOXE3 2
# NOX5 2
# FOXRED1 2
# KLHL10 2
# DET1 2
# KLHL36 2
# THAP4 2
# CSNK1D 2
# KBTBD4 2
# CDK3 2
# DDX59 2
# EP300 2
# VAMP2 2
# PRKDC 2
# SSBP1 2
# RPS15A 2
# NLRP12 2
# TTC1 2
# TGM2 2
# HSPH1 2
# EDRF1 2
# HYOU1 2
# DNAJA4 2
# DUT 2
# ARFIP1 2
# SF3A3 2
# TAB1 2
# SP1 2
# ALK 2
# MAPK6 2
# MYC 2
# SIRT1 2
# SIRT3 2
# HSPE1 2
# ASB4 2
# AURKB 2
# FBXO17 2
# DNAJC17 2
# GBAS 2
# XRCC3 2
# PRDM1 2
# PUF60 2
# EIF2AK3 2
# TERF2 2
# POLR2E 2
# OS9 2
# CCT2 2
# LYN 2
# BLK 2
# LIMK2 2
# IKBKG 2
# APAF1 2
# DNM1L 2
# CSNK2A2 2
# ERBB2 2
# AIMP1 2
# CAP1 2
# CDC37L1 2
# MCM3 2
# SEL1L 2
# SMG1 2
# STAT3 2
# IRS4 2
# FKBP5 2
# TGFBR1 2
# TGFBR2 2
# PAK1 2
# PRKCZ 2
# PRKAA1 2
# PRKCI 2
# TERT 2
# BCL6 2
# AGO2 2
# PRKACB 2
# CDK5 2
# PSMD10 2
# CDC25C 2
# PCBP1 2
# CLK3 2
# UBE2N 2
# NSL1 2
# TAB2 2
# PRR14L 2
# PGK1 2
# MTHFD1 2
# NANS 2
# TPM3 2
# MYH9 2
# TNK1 2
# MAP2K5 2
# SGK1 2
# MAP3K2 2
# FBXW11 2
# BTRC 2
# VPS18 2
# ZBTB17 2
# TRIM32 2
# TNFAIP3 2
# VPS41 2
# MDM4 2
# HMGA1 2
# RPS6KA5 2
# HIPK4 2
# MAPK4 2
# STK38 2
# PRKCE 2
# PRKCA 2
# LIMK1 2
# MAP3K5 2
# PRKD1 2
# IKBKE 2
# PAK6 2
# HSPA1B 2
# MAGED2 2
# ATP5A1 2
# HK2 2
# POT1 2
# IQGAP1 2
# ALDOC 2
# ASNS 2
# MAPRE1 2
# SNRPF 2
# PYGL 2
# FAN1 2
# YAP1 2
# ECHS1 2
# COQ2 2
# PARK7 2
# XRCC6 2
# LRP1 2
# PIGK 2
# LCT 2
# CD1D 2
# EBI3 2
# CD3D 2
# F8 2
# SLC6A4 2
# SLC2A1 2
# SLC4A1 2
# SVIP 2
# BSCL2 2
# ZNRF4 2
# Tor1aip1 2
# L1CAM 2
# TCF3 2
# UBXN4 2
# POMP 2
# EDEM1 2
# OPRD1 2
# LPA 2
# TOR1A 2
# PKD2 2
# PGRMC1 2
# SMURF2 2
# CLN5 2
# NPHS1 2
# TRAF6 2
# PMP22 2
# BMI1 2
# FOXRED2 2
# EMC1 2
# PPT1 2
# OGFOD3 2
# POMK 2
# POGLUT1 2
# WNT3A 2
# CHST8 2
# PLTP 2
# CHST9 2
# APMAP 2
# ATP1B1 2
# ATP2B1 2
# ATP2B3 2
# ATP2B4 2
# CCT4 2
# DARS 2
# PDIA6 2
# PTBP1 2
# RPS5 2
# SEC61B 2
# LNPEP 2
# CHST15 2
# Prkacb 2
# Ncstn 2
# Spire2 2
# EDEM2 2
# TMEM258 2
# ACP5 2
# CD1E 2
# P2RX2 2
# CLEC2D 2
# BRINP2 2
# GXYLT1 2
# NRROS 2
# CHST6 2
# TMEM5 2
# LIPG 2
# HYAL3 2
# ADAM21 2
# UST 2
# CD1B 2
# DPEP3 2
# DNASE2 2
# GABRG2 2
# ADAM30 2
# P2RX5 2
# TMPRSS11B 2
# AMIGO3 2
# IL27RA 2
# MPPE1 2
# CPA5 2
# DCT 2
# ST3GAL2 2
# WNT16 2
# OPCML 2
# GAL3ST1 2
# FUCA2 2
# C12orf49 2
# NCEH1 2
# SMPD1 2
# B3GNT3 2
# CCNJL 2
# AGT 2
# ARSG 2
# FUT9 2
# TOR3A 2
# A4GALT 2
# IGSF6 2
# TRHDE 2
# GPR114 2
# TMPRSS3 2
# SERPINA5 2
# SCNN1D 2
# CHST14 2
# TMED6 2
# WNT7A 2
# ST8SIA3 2
# PTPRE 2
# MTNR1B 2
# TF 2
# TSHR 2
# Edem1 2
# CHRNA5 2
# SERPINF2 2
# ASGR1 2
# ABCC1 2
# ABCC3 2
# ATP13A1 2
# CCT6A 2
# IDH3A 2
# KDSR 2
# MOGS 2
# NCLN 2
# PC 2
# GGT1 2
# EXT2 2
# DNAJC8 2
# OSGEP 1
# DSTYK 1
# SGSM3 1
# TBC1D15 1
# TBC1D17 1
# FLOT1 1
# LAMTOR3 1
# ZMPSTE24 1
# ATP4A 1
# LGALS1 1
# RAB10 1
# RAB11B 1
# RAP1A 1
# RAP1B 1
# GDI1 1
# LIMA1 1
# Actb 1
# Rab5b 1
# Kctd5 1
# Flnb 1
# DUSP22 1
# DUSP8 1
# DUSP9 1
# SUN2 1
# EEA1 1
# APPL2 1
# ARF1 1
# ARL8A 1
# LDHAL6A 1
# LDHAL6B 1
# RAB8A 1
# RAB8B 1
# ATP6V0A1 1
# CLCN7 1
# COX5B 1
# FLOT2 1
# H3F3A 1
# IGF2R 1
# NDUFB7 1
# NDUFS1 1
# NDUFS5 1
# CHMP1A 1
# PPIA 1
# SS18 1
# TFRC 1
# TTC3 1
# STX7 1
# GPRC5A 1
# ATP6V0D1 1
# XPR1 1
# COPS2 1
# GOSR1 1
# CLINT1 1
# PIEZO1 1
# IST1 1
# C2CD5 1
# CKAP4 1
# TMED10 1
# IMMT 1
# RASSF8 1
# KDM2A 1
# WDFY3 1
# SCFD1 1
# HAUS5 1
# GLTSCR1L 1
# GCA 1
# LETMD1 1
# CHMP2B 1
# MYOF 1
# ATP2C1 1
# CHMP2A 1
# ABT1 1
# NDUFB11 1
# CHCHD3 1
# OCIAD1 1
# IMPACT 1
# TTC17 1
# MUC13 1
# KIDINS220 1
# SUGP1 1
# MRPS14 1
# SLC35E1 1
# ZCRB1 1
# GADD45GIP1 1
# ACBD5 1
# SLC38A5 1
# PRKCDBP 1
# LRR1 1
# MRPL55 1
# MITD1 1
# RAB43 1
# CHM 1
# GNAT3 1
# CHML 1
# GDI2 1
# DLG4 1
# FZD4 1
# MRGPRX1 1
# LPAR3 1
# NDP 1
# OXER1 1
# BAG6 1
# ZNRF3 1
# LGR6 1
# GNAQ 1
# GNB1 1
# GNG2 1
# Dvl3 1
# PDZRN3 1
# E2F1 1
# RBL1 1
# RBL2 1
# BRE 1
# CLN3 1
# SYNCRIP 1
# PARP1 1
# AFG3L2 1
# ATP1A1 1
# ATP5L 1
# COX4I1 1
# GOSR2 1
# MTCH2 1
# NDUFB4 1
# SCAMP2 1
# SSR1 1
# TAGLN2 1
# TPD52 1
# UQCRQ 1
# VDAC3 1
# FAP 1
# MED20 1
# MED23 1
# AKAP1 1
# EMC2 1
# MTX2 1
# FGFR1OP2 1
# TMEM63B 1
# MMGT1 1
# Atp2a2 1
# C1qbp 1
# Eef1a1 1
# Aifm1 1
# Mtx2 1
# Rab11a 1
# Tmed2 1
# Rmdn3 1
# Tmem109 1
# NF2 1
# ARMC7 1
# TPTE 1
# ANXA2 1
# COL9A2 1
# IGHG1 1
# ACTB 1
# LMNA 1
# SMG5 1
# PLEC 1
# RAPH1 1
# DBN1 1
# LONRF3 1
# COX6C 1
# NAP1L1 1
# BCAP29 1
# BCAS3 1
# CASC3 1
# CCL5 1
# ST14 1
# C11orf73 1
# STOM 1
# RAN 1
# YRB1 1
# DIS3 1
# NUTF2 1
# XPO6 1
# SMARCB1 1
# NUP153 1
# RANGRF 1
# RCC1 1
# RANBP1 1
# RANBP2 1
# RANBP10 1
# KPNB1 1
# RANBP9 1
# XPO5 1
# RANBP3 1
# IPO5 1
# rna1 1
# RANGAP1 1
# SNUPN 1
# NTF2A 1
# NTF2B 1
# H2AFY 1
# SLX1B 1
# TAF6 1
# Nup88 1
# Csnk1e 1
# Nup188 1
# IPO13 1
# UL27 1
# RAPGEF3 1
# TFAP4 1
# MAD2L2 1
# Nutf2 1
# Nxt1 1
# SF3B6 1
# EXOSC2 1
# PTMA 1
# ASB16 1
# MSL1 1
# NUPR1 1
# CSE1L 1
# EIF3I 1
# KPNA1 1
# KPNA6 1
# PSMA4 1
# SKIV2L 1
# TNPO1 1
# KMT2A 1
# UBE2I 1
# KIF3A 1
# CCDC88A 1
# NUP107 1
# Ranbp1 1
# Ube2i 1
# Immt 1
# Rcc1 1
# Nup107 1
# Nup98 1
# EIF2S2 1
# CRM1 1
# AKIRIN2 1
# XPOT 1
# TNPO2 1
# XPO7 1
# XPO4 1
# TPR 1
# RBM39 1
# U2AF1 1
# RGPD5 1
# PFDN4 1
# Rangap1 1
# AGL 1
# EIF6 1
# KPNA5 1
# RANBP6 1
# RGPD2 1
# RGPD8 1
# TMEM194B 1
# DLGAP5 1
# CDCA2 1
# TMEM194A 1
# NUP214 1
# AKIRIN1 1
# NUP62 1
# IKBIP 1
# BAG1 1
# TCERG1 1
# PPP1R15A 1
# HDAC3 1
# CITED1 1
# HSPBP1 1
# TADA3 1
# RGS2 1
# RBX1 1
# CYCS 1
# POLR3D 1
# STMN1 1
# GOT2 1
# GPR37 1
# HNRNPD 1
# RUVBL1 1
# GPN1 1
# PACSIN1 1
# HDAC10 1
# CCND1 1
# MEN1 1
# IL16 1
# CENPA 1
# WDR82 1
# CDK5RAP3 1
# LALBA 1
# CLTA 1
# DGCR8 1
# MME 1
# TLR4 1
# TLR9 1
# INSIG2 1
# HMGB1 1
# Psma2 1
# lqf 1
# clint1-a 1
# ATXN1 1
# DNAJB2 1
# PPP1CC 1
# PPP1CA 1
# PSMA2 1
# FAF1 1
# KCND3 1
# BCAS2 1
# CWC15 1
# HTT 1
# CAPZB 1
# DNAJB14 1
# INPPL1 1
# PIK3R2 1
# CRK 1
# EPS15 1
# AP2M1 1
# ATP13A2 1
# RAD23A 1
# Bax 1
# DNAJB12 1
# SRRT 1
# METTL21A 1
# METTL21C 1
# LAMP2 1
# HLTF 1
# TOPBP1 1
# RELA 1
# ATXN10 1
# NAPRT 1
# SHFM1 1
# ZBTB1 1
# TRIM5 1
# IVNS1ABP 1
# AIRE 1
# HAUS1 1
# HAUS2 1
# TUBGCP2 1
# TUBGCP4 1
# IL32 1
# C17orf49 1
# SUMO2 1
# SIRT6 1
# CCNI2 1
# DRG2 1
# LPGAT1 1
# POC1A 1
# VASH1 1
# EBNA1BP2 1
# FAM189B 1
# KIAA1191 1
# NXF5 1
# USP46 1
# VSX1 1
# ZSCAN32 1
# WDR37 1
# APBB2 1
# NDRG2 1
# KCNJ10 1
# DENND2D 1
# CYP3A4 1
# KNSTRN 1
# CAD 1
# CPS1 1
# GRPEL1 1
# PABPC1 1
# ATM 1
# AKAP5 1
# LRPPRC 1
# KIAA1107 1
# SDHAF2 1
# CDCA5 1
# Tgfbr1 1
# ID2 1
# HEMGN 1
# ALKBH3 1
# HTN3 1
# OTUB1 1
# NANOG 1
# POU5F1 1
# ZNF618 1
# PHF8 1
# RFX1 1
# HSF2 1
# ARMC1 1
# PDPK1 1
# TBC1D23 1
# GMNN 1
# HMCES 1
# FLYWCH2 1
# CYP8B1 1
# SNX20 1
# ABHD15 1
# KCND2 1
# VILL 1
# SLC27A3 1
# TCAP 1
# DGCR14 1
# GNA15 1
# C21orf59 1
# NUS1 1
# CSNK1E 1
# FAM73B 1
# FUZ 1
# DCDC2B 1
# VWA2 1
# PRODH 1
# CDK10 1
# TRIM16L 1
# ARNT 1
# CNN2 1
# RNF34 1
# GFAP 1
# C19orf45 1
# HCFC2 1
# SPATA5L1 1
# TRMT12 1
# CAPG 1
# LRRC56 1
# NMNAT3 1
# VSIG8 1
# TYSND1 1
# SSMEM1 1
# THSD4 1
# TTC30B 1
# KCNV2 1
# DSCR4 1
# SETMAR 1
# ZNF488 1
# VANGL2 1
# EPB42 1
# LEPREL2 1
# HAO2 1
# BPNT1 1
# FRMD8P1 1
# PRKACG 1
# CHD1L 1
# AGPAT3 1
# NPAS1 1
# DHX57 1
# CPLX4 1
# GPR6 1
# PNPLA5 1
# KCNC4 1
# PANK2 1
# NLRX1 1
# IER2 1
# CFAP52 1
# HTR1E 1
# BBS1 1
# POLE 1
# PPEF1 1
# C9orf116 1
# EXOC3L2 1
# C1orf94 1
# SSH3 1
# F12 1
# GK2 1
# TAF6L 1
# DOCK5 1
# FCRL3 1
# C20orf96 1
# TSPYL6 1
# MVP 1
# IL17RC 1
# ARHGEF16 1
# CHI3L1 1
# CDKL3 1
# MPZL1 1
# RCCD1 1
# GLIPR1 1
# NOA1 1
# TM4SF1 1
# ERH 1
# FBP1 1
# PPP1R12B 1
# RNPS1 1
# HNRNPA3 1
# SAMM50 1
# SEC24C 1
# RPL18A 1
# NECAP2 1
# RPL8 1
# SEC31A 1
# POU2F1 1
# ASNA1 1
# TUBA4B 1
# YARS 1
# DNAJB6 1
# GABRB1 1
# HSPA4L 1
# AMT 1
# NMI 1
# TRIM38 1
# APOA1BP 1
# DNAJC1 1
# DNAJC13 1
# FDPS 1
# LMNB1 1
# NACA 1
# RPL13A 1
# RNF207 1
# CD207 1
# ABL2 1
# GAK 1
# HIST2H3PS2 1
# RPRD2 1
# TBCE 1
# C6orf106 1
# SRP54 1
# TACC3 1
# MAPRE2 1
# ZNF703 1
# KCTD15 1
# HBB 1
# HBA2 1
# HDLBP 1
# HIST1H1B 1
# NFS1 1
# MAP2K2 1
# QRICH1 1
# ENDOG 1
# CKAP5 1
# PPP1R8 1
# MAVS 1
# RNF25 1
# MAD1L1 1
# FOXC1 1
# ATF1 1
# CSTF3 1
# ALB 1
# CYB5R3 1
# CSDE1 1
# MYB 1
# CREBBP 1
# DHFR 1
# CA2 1
# CASP3 1
# ALDH2 1
# SRRM2 1
# PPP2R2C 1
# SPG20 1
# PCK1 1
# ASB9 1
# HSPA14 1
# PAXIP1 1
# HCVgp1 1
# PLG 1
# CLEC7A 1
# DDX39B 1
# EIF4E 1
# EIF5A 1
# GDA 1
# GSR 1
# MAPK14 1
# NAGK 1
# OXCT1 1
# PTMS 1
# C11orf58 1
# SMS 1
# THOP1 1
# TRIM63 1
# NFAM1 1
# SLC25A41 1
# ATP5F1 1
# TAZ 1
# DCAF5 1
# MRPL4 1
# OXNAD1 1
# SIRT4 1
# QTRT1 1
# MRPL37 1
# TTC39B 1
# THBS3 1
# KIAA0101 1
# KIF2C 1
# PREP 1
# REXO2 1
# SCARNA22 1
# PLCG2 1
# DDB2 1
# LAMB3 1
# PCK2 1
# NIPSNAP1 1
# HMG20A 1
# FBXO7 1
# BCOR 1
# CDKN2AIP 1
# DCLRE1B 1
# TUBA1C 1
# Gnb1 1
# Hax1 1
# Ska1 1
# Cdkn2aip 1
# Ckap5 1
# Wdr5 1
# Sept9 1
# FOXL1 1
# DEFA5 1
# ASIC4 1
# GTPBP8 1
# DCAF4 1
# RELL2 1
# GORASP1 1
# C4orf29 1
# TFB1M 1
# NDUFS7 1
# RPUSD3 1
# TRIM43 1
# RASL10B 1
# BCAT2 1
# CYB5A 1
# TRIB2 1
# HARS2 1
# MTG2 1
# METTL17 1
# SET 1
# MRPS30 1
# TRUB2 1
# GPX7 1
# XAGE1B 1
# NEU4 1
# KLHL33 1
# YBEY 1
# SLC25A43 1
# PRAMEF17 1
# TRIM35 1
# FBXO15 1
# BPHL 1
# SNRNP27 1
# GMFG 1
# GSTK1 1
# YARS2 1
# MRPL16 1
# OXCT2 1
# GLB1L3 1
# METTL8 1
# IDH3G 1
# PDK3 1
# DKK3 1
# HIST2H2BE 1
# BAK1 1
# BAX 1
# HNRNPA2B1 1
# DDX17 1
# EEF1B2 1
# HEXIM1 1
# SEPT9 1
# CXorf56 1
# MCCC2 1
# SCARB2 1
# SAP30BP 1
# UBR4 1
# FTL 1
# NCAPD2 1
# PTPN2 1
# COLGALT1 1
# RAB5B 1
# GID8 1
# PAF1 1
# STRN4 1
# LAMB1 1
# PPA1 1
# PLOD3 1
# SARNP 1
# KRTAP5-9 1
# KRT31 1
# RGS20 1
# TMCC2 1
# CEP70 1
# LZTS2 1
# KRT40 1
# SAMD3 1
# KRTAP10-8 1
# KRTAP10-3 1
# NOTCH2NL 1
# GLOD4 1
# GMPPB 1
# SLC25A33 1
# TANGO2 1
# ACSF3 1
# TRMU 1
# ACSS1 1
# FECH 1
# FTSJ2 1
# SDR39U1 1
# SLC25A39 1
# NUDT19 1
# MTG1 1
# TRMT2B 1
# PUSL1 1
# MARS2 1
# NSUN4 1
# ACSF2 1
# NARS2 1
# NIPSNAP3A 1
# FAHD2B 1
# TMEM70 1
# TRMT1L 1
# GFM1 1
# PUS1 1
# IBA57 1
# DARS2 1
# CTSH 1
# CECR5 1
# VWF 1
# RAE1 1
# UBA5 1
# RNF185 1
# ERLEC1 1
# FMNL1 1
# METTL23 1
# NKX3-1 1
# KDM4B 1
# MLLT3 1
# KIAA1598 1
# PHAX 1
# TPM1 1
# TRIM68 1
# BIRC2 1
# AK9 1
# CALU 1
# CLGN 1
# CTSD 1
# HNRNPU 1
# SUCLG2 1
# TSR1 1
# ZBTB8OS 1
# KIF20B 1
# UGGT1 1
# Mgp 1
# Sel1l 1
# Calml3 1
# Tuba3a 1
# KIT 1
# ompA 1
# LYZL2 1
# SMARCC2 1
# PCNA 1
# GNB2L1 1
# TXNDC11 1
# KIAA1468 1
# USP25 1
# MARS 1
# SRSF9 1
# USO1 1
# EBP 1
# C15orf39 1
# KLF16 1
# BRINP1 1
# STAT1 1
# SMYD3 1
# STARD13 1
# CHTF18 1
# NOS3 1
# GUCY1B3 1
# FES 1
# RPS3A 1
# DAP3 1
# SIM1 1
# PIM1 1
# FNIP1 1
# TAH1 1
# ERN1 1
# AHR 1
# PPARA 1
# GNA12 1
# FLT3 1
# GUCY1A2 1
# DAPK1 1
# SWE1 1
# RIPK1 1
# RPS3 1
# COPS3 1
# TTI2 1
# STK11 1
# FKBP4 1
# AIP 1
# VEGFA 1
# SMYD2 1
# HES1 1
# PI4K2B 1
# PI4K2A 1
# RARRES3 1
# CDK5R1 1
# MAP3K3 1
# MYOCD 1
# FBXW8 1
# TOM70 1
# MAP3K7 1
# Nos1 1
# EIF2AK1 1
# SVIL 1
# CALM1 1
# FKBPL 1
# BCL2 1
# ATR 1
# REV1 1
# Dnajc7 1
# Stub1 1
# Crnkl1 1
# PPIL2 1
# LCK 1
# FYN 1
# FKBP8 1
# SLC2A4 1
# ALG2 1
# RCAN1 1
# PTGES3 1
# RNF114 1
# PINK1 1
# POLH 1
# TNK2 1
# NLRP3 1
# NLRP2 1
# NOD1 1
# NLRP4 1
# MIF 1
# STRADA 1
# PIWIL2 1
# STK36 1
# GSK3B 1
# CSNK1A1 1
# GRK6 1
# MID1 1
# MET 1
# HDAC8 1
# BRMS1 1
# DSN1 1
# BLM 1
# NUDC 1
# PAFAH1B1 1
# NUDCD2 1
# ACVRL1 1
# STK33 1
# TYMP 1
# IP6K2 1
# MTRNR2L1 1
# IRF3 1
# PACRG 1
# HSP90AB3P 1
# HSP90AA5P 1
# HSP90AB2P 1
# WASL 1
# CFLAR 1
# CHEK1 1
# AMHR2 1
# ICK 1
# PSKH1 1
# MAP3K8 1
# DDR2 1
# GSK3A 1
# TSSK2 1
# ROR2 1
# MAP3K9 1
# EPHA2 1
# AKT2 1
# FGR 1
# TOMM70A 1
# TBK1 1
# IFIT1 1
# AGO1 1
# METTL18 1
# ILF3 1
# US3 1
# FAM162A 1
# MAP3K11 1
# AXL 1
# IRF1 1
# PIK3C3 1
# RBCK1 1
# TOMM40 1
# PGR 1
# LSM1 1
# CERS2 1
# Nr3c1 1
# KATNA1 1
# KEAP1 1
# CKS2 1
# CKS1B 1
# Stk11 1
# GZMA 1
# MGEA5 1
# PPP6R3 1
# RHOBTB2 1
# USP19 1
# PRKACA 1
# ADRBK1 1
# RPS6KA1 1
# CHORDC1 1
# FKBP6 1
# TTC4 1
# UNC45B 1
# CEP57 1
# CEP76 1
# CDK1 1
# PTGDS 1
# PTGDR 1
# TRAF3IP2 1
# WDR76 1
# AGO3 1
# PSKH2 1
# MYLK4 1
# CDKL2 1
# CDKL4 1
# AURKC 1
# CDK15 1
# CDK18 1
# CDK7 1
# CDK13 1
# NES 1
# Cdc37 1
# Myo1c 1
# Lrr1 1
# RHOBTB3 1
# EGLN1 1
# UNC45A 1
# RPAP3 1
# TTK 1
# EIF2S1 1
# CRBN 1
# UHRF1 1
# FLCN 1
# FNIP2 1
# AKT3 1
# CDK11A 1
# STK35 1
# GBP2 1
# ANKMY2 1
# PDIK1L 1
# BTK 1
# RALBP1 1
# ARNTL 1
# NPAS2 1
# SRC 1
# AHSA2 1
# TJP1 1
# RPS6 1
# BECN1 1
# SKP1 1
# CHUK 1
# MAP3K14 1
# HIF3A 1
# Ppard 1
# Pparg 1
# Ppara 1
# PPARD 1
# HOPX 1
# PMF1 1
# MIS12 1
# Tgfbr2 1
# NCL 1
# RPL17 1
# RPL32 1
# RPL5 1
# RPS16 1
# TXNDC5 1
# RPS20 1
# MARCKS 1
# RPL3 1
# SUPT5H 1
# RPL23A 1
# RPL29 1
# MYLK2 1
# TTC9C 1
# PLCE1 1
# EFTUD2 1
# CNOT6 1
# PRPF8 1
# FLII 1
# CALD1 1
# NUDCD3 1
# FAM83H 1
# CACYBP 1
# CEP97 1
# DYNC1H1 1
# SCRIB 1
# TOMM34 1
# SNRNP200 1
# PIH1D1 1
# URI1 1
# MLF2 1
# YTHDC2 1
# HSPA7 1
# HSPA1L 1
# TCP1 1
# MDH1 1
# PSAT1 1
# FASN 1
# FLNA 1
# NUMA1 1
# UBA1 1
# PSMD1 1
# AARS 1
# EIF3H 1
# IARS2 1
# RPSA 1
# EIF2AK2 1
# FER 1
# PKN2 1
# MAST2 1
# MERTK 1
# DYRK4 1
# TIE1 1
# NPRL2 1
# TESK2 1
# MAP3K6 1
# EPHB6 1
# CSF1R 1
# MAP3K12 1
# EPHB1 1
# ACVR1C 1
# FASTK 1
# KSR2 1
# BMPR1A 1
# FRK 1
# PRKY 1
# MOS 1
# MAP3K15 1
# MYO3B 1
# SGK2 1
# INSRR 1
# ALPK1 1
# GRK4 1
# TNNI3K 1
# FGFR1 1
# MATK 1
# ITK 1
# NTRK3 1
# FLT4 1
# ACVR1B 1
# DCLK2 1
# NTRK2 1
# MAP4K4 1
# ACVR2B 1
# SGK3 1
# CAMKK1 1
# NEK11 1
# KSR1 1
# PRKCB 1
# WNK4 1
# SRPK1 1
# STYK1 1
# HCK 1
# PRKG2 1
# MAP2K7 1
# MAPK15 1
# PRKX 1
# JAK1 1
# TP53RK 1
# FBXW2 1
# FBXO38 1
# TRIM56 1
# KLHL38 1
# FBXO24 1
# FBXL3 1
# WSB2 1
# FBXL2 1
# FBXL12 1
# KLHL6 1
# ENC1 1
# KCTD8 1
# KLHL25 1
# FBXL14 1
# FBXW7 1
# FBXO9 1
# KLHL22 1
# PRPF19 1
# KLHL26 1
# RAPSN 1
# FBXO18 1
# FBXL15 1
# FBXL8 1
# TRIM17 1
# FBXL18 1
# RNF19B 1
# RNF10 1
# ARMC5 1
# KLHL14 1
# FBXO28 1
# FBXO27 1
# FBXL13 1
# NHLRC1 1
# SF3B3 1
# KBTBD7 1
# FBXO3 1
# RAB40A 1
# ANAPC2 1
# AREL1 1
# KLHL15 1
# WWP1 1
# PCGF1 1
# HECTD3 1
# TRIM49 1
# KLHL1 1
# TRIM10 1
# KLHL23 1
# TRIM2 1
# ZBTB20 1
# KLHL29 1
# KLHL32 1
# SH3RF2 1
# ASB3 1
# KLHL13 1
# PCGF3 1
# HERC6 1
# RHOBTB1 1
# FBXO40 1
# FBXW5 1
# KCNG1 1
# SPSB3 1
# TRIM36 1
# DTX4 1
# ASB6 1
# ZBTB49 1
# MARCH9 1
# LRSAM1 1
# FBXO4 1
# TRIM74 1
# RCBTB2 1
# RCBTB1 1
# ASB17 1
# PCGF6 1
# KCNS3 1
# TRIM73 1
# SPSB1 1
# KCNA6 1
# SOCS6 1
# HERC4 1
# TRIM41 1
# TRIM7 1
# G2E3 1
# RNF111 1
# RNF40 1
# FBXO34 1
# FBXO10 1
# TRIM37 1
# RGS11 1
# RGS6 1
# PREB 1
# ZBED4 1
# RAG1 1
# ZC3H7B 1
# FOXD4L6 1
# NR3C2 1
# POGK 1
# NR1H3 1
# RGS7 1
# STAT2 1
# NR2C2 1
# GTF2IRD2 1
# DLX6 1
# NR1I3 1
# HP1BP3 1
# SREBF1 1
# NFRKB 1
# KAT5 1
# IRF2 1
# TFDP3 1
# TEAD2 1
# C20orf194 1
# LARP4B 1
# ZNF74 1
# SIM2 1
# NR1I2 1
# TBX22 1
# CXXC1 1
# DMRTA1 1
# SETDB1 1
# NFIC 1
# SLFN11 1
# ZNF215 1
# TCF25 1
# ISX 1
# TADA2A 1
# ATF3 1
# CEBPE 1
# FOXP2 1
# MKX 1
# MAX 1
# FOXM1 1
# MAFG 1
# TSSK3 1
# YES1 1
# SGK223 1
# IRAK2 1
# NEK8 1
# CAMK2G 1
# DYRK1B 1
# PDGFRB 1
# PRKCQ 1
# TYRO3 1
# RPS6KL1 1
# PKN1 1
# DDR1 1
# GRK7 1
# EPHA1 1
# PRKCG 1
# SRPK3 1
# PIM3 1
# TESK1 1
# NUAK2 1
# PRKCH 1
# MAP4K1 1
# MYLK3 1
# RET 1
# CDK6 1
# RPS6KB1 1
# RPS6KC1 1
# PRKAA2 1
# RPS6KA2 1
# STK38L 1
# RPS6KA6 1
# EPHA4 1
# IRAK3 1
# DMPK 1
# CAMKV 1
# CAMK1G 1
# PIM2 1
# BMX 1
# STK32B 1
# IGF1R 1
# TAOK3 1
# PTK6 1
# ERBB4 1
# PASK 1
# CDK14 1
# MUSK 1
# PTK2 1
# STK32C 1
# MAP4K2 1
# PTK2B 1
# MINK1 1
# DAPK3 1
# CAMKK2 1
# CAMK4 1
# PRKD2 1
# CAMK2A 1
# CAMK2B 1
# CAMK2D 1
# CLK2 1
# GIGYF2 1
# TUBB2B 1
# PDRG1 1
# TUBAL3 1
# MMP2 1
# SSR4 1
# VARS 1
# PRPF4B 1
# COBLL1 1
# SKIV2L2 1
# ZMYM1 1
# FAM103A1 1
# WDR20 1
# WEE1 1
# LLGL1 1
# FZR1 1
# MAGEA4 1
# HLA-A 1
# ARNT2 1
# TRIM69 1
# WBP2 1
# UQCRB 1
# TEKT4 1
# TK1 1
# AMOTL2 1
# BEX2 1
# TIGD5 1
# AMOT 1
# PPP1R13L 1
# MAGEB16 1
# MAGEA9B 1
# MAGEA10 1
# MDM1 1
# FXR1 1
# AMOTL1 1
# RAD18 1
# TSPYL4 1
# RPL7L1 1
# DCAF6 1
# TSPYL1 1
# CCDC85B 1
# ASCC2 1
# NDUFA2 1
# ARPC1A 1
# gag 1
# GSS 1
# RAP1GDS1 1
# ZNF346 1
# GNL3L 1
# WWP2 1
# PRPF3 1
# PRPF4 1
# PPIH 1
# ACAT2 1
# TXNRD1 1
# PRPF31 1
# ALYREF 1
# LSM4 1
# LSM8 1
# RPL26L1 1
# SART3 1
# MCC 1
# DMWD 1
# WIPI2 1
# TINF2 1
# ACD 1
# PFKL 1
# PFKM 1
# PFKP 1
# CD81 1
# ARHGDIA 1
# CDA 1
# COMMD4 1
# ELAC2 1
# METTL13 1
# RSU1 1
# UBA6 1
# Mad2l1 1
# EID1 1
# RNF126 1
# Ostm1 1
# NELL1 1
# IFT122 1
# WDR19 1
# CRYZ 1
# PPIB 1
# VAT1 1
# ALDH16A1 1
# ARHGAP1 1
# CCDC22 1
# MCFD2 1
# MCMBP 1
# NMD3 1
# NPEPL1 1
# OXSR1 1
# PLCG1 1
# PSMG1 1
# PTPN6 1
# SAMD9 1
# TXLNA 1
# Mlxipl 1
# REM1 1
# TSC1 1
# TSC2 1
# VIM 1
# FOXO1 1
# HMGN1 1
# GP1BA 1
# GP1BB 1
# CSF2RB 1
# SYN2 1
# CDC25B 1
# LYST 1
# TPH1 1
# UCP2 1
# UCP3 1
# CDK16 1
# Usp8 1
# HRR25 1
# MEPCE 1
# HDAC7 1
# MAP3K4 1
# MEF2C 1
# EXO1 1
# CHAF1A 1
# UCHL5 1
# DISC1 1
# OPTN 1
# GABARAPL2 1
# SH3GL1 1
# SNX24 1
# KAT8 1
# HIST1H3A 1
# PTPN14 1
# MARK3 1
# MEX3B 1
# ARHGEF2 1
# PPP1R14A 1
# ECT2 1
# MDC1 1
# TP53BP1 1
# HNF1A 1
# ITGB2 1
# gag-pol 1
# CBX4 1
# SQSTM1 1
# HDAC4 1
# BAD 1
# EFNB3 1
# SSFA2 1
# PRDX2 1
# KLF11 1
# SORBS2 1
# PIAS1 1
# RPRD1A 1
# SSX2IP 1
# Wwtr1 1
# Yap1 1
# TBXA2R 1
# RASSF2 1
# SAV1 1
# CAPNS1 1
# EIF5 1
# ERP44 1
# FERMT2 1
# G6PD 1
# GINS4 1
# ISOC1 1
# SLC9A3R1 1
# UBE2V1 1
# SIK3 1
# SIK2 1
# DTL 1
# ENO1 1
# SHMT2 1
# FAM65B 1
# MAST1 1
# AKT1S1 1
# MTOR 1
# KIAA0930 1
# CDCA7 1
# SFN 1
# NKD2 1
# TESPA1 1
# STAC 1
# FAM189A2 1
# DMTN 1
# EIF4B 1
# NCAPD3 1
# SLK 1
# YWHAH 1
# LCA5 1
# Cenpe 1
# CRY1 1
# TBC1D4 1
# ATG9A 1
# MAPKAPK2 1
# PPM1H 1
# PTPN3 1
# PTPN4 1
# CDC25A 1
# MTMR4 1
# SMTNL2 1
# CGN 1
# SPATA13 1
# SAMD4A 1
# PLEKHG5 1
# PRICKLE3 1
# RIN1 1
# TFEB 1
# PAK7 1
# REEP1 1
# FAM163A 1
# CRTC2 1
# RAB11FIP1 1
# RALGPS2 1
# FAM53C 1
# ABLIM1 1
# EPB41L2 1
# SSH1 1
# ANKRD55 1
# SAMD4B 1
# ZNF397 1
# TEX33 1
# PTPDC1 1
# GJA1 1
# KIF5B 1
# EPB41L3 1
# USP8 1
# DFFA 1
# KLC1 1
# TJP2 1
# NOLC1 1
# RAI14 1
# EDC3 1
# KLC4 1
# NADK 1
# RPL31 1
# NCKAP1 1
# HNRNPL 1
# PABPC4 1
# LARP1 1
# SF3B1 1
# RRAD 1
# AANAT 1
# FOXO3 1
# IL9R 1
# INPP5A 1
# RGS3 1
# NFATC4 1
# HIVEP2 1
# LCP2 1
# LRMP 1
# TNS1 1
# MADD 1
# EIF3A 1
# HDAC9 1
# KIAA0232 1
# MPHOSPH9 1
# SYNPO 1
# RAP1GAP2 1
# NEDD4L 1
# WWTR1 1
# FHOD1 1
# FAM13B 1
# MSL2 1
# ZNF839 1
# CENPJ 1
# RASAL3 1
# WNK2 1
# CGNL1 1
# SIMC1 1
# ING1 1
# SAMSN1 1
# SIK1 1
# TRIM21 1
# TUBA3C 1
# ADORA3 1
# SNRPD2P1 1
# PARD6A 1
# MARK2 1
# DCAF7 1
# PNMA2 1
# KIF23 1
# MARK1 1
# CYFIP1 1
# PNMA1 1
# DOCK7 1
# CYFIP2 1
# HIST1H4A 1
# TCEB3 1
# BRD4 1
# PSMA5 1
# ZHX2 1
# AJUBA 1
# POTEKP 1
# ZAK 1
# PAK2 1
# PFAS 1
# VCL 1
# YWHAG 1
# ZFYVE19 1
# DDIT4 1
# PCNT 1
# PRCC 1
# TP53BP2 1
# SMC1A 1
# AP3B1 1
# PRPF18 1
# IRS2 1
# SNRNP40 1
# CWC27 1
# SRSF8 1
# B4GALT7 1
# RAB11FIP2 1
# UHRF1BP1L 1
# MYCBP2 1
# NBEAL2 1
# PHF3 1
# TIMM13 1
# SEC61A1 1
# SDF4 1
# RBM27 1
# BDP1 1
# KLHL7 1
# RBM26 1
# COPS7B 1
# PCGF5 1
# SPIRE2 1
# SPRYD3 1
# HS6ST2 1
# WDR62 1
# CCDC84 1
# PPFIBP1 1
# KIF11 1
# CEP131 1
# PCM1 1
# SARM1 1
# ATP6V1F 1
# MCM7 1
# EZH2 1
# SCNN1A 1
# C1orf123 1
# DNAJB5 1
# NAPA 1
# OFD1 1
# CNTRL 1
# FBF1 1
# NPHP1 1
# DCTN1 1
# SGTB 1
# Tpm4 1
# POLR1C 1
# NUP37 1
# ARMCX3 1
# BIN1 1
# KIF13A 1
# MSH6 1
# XRCC5 1
# ETF1 1
# HK1 1
# NUP205 1
# ALOX5 1
# TRAP1 1
# EXT1 1
# TGFBRAP1 1
# SMAD4 1
# UVRAG 1
# RYK 1
# PSMC4 1
# ESX1 1
# OGFR 1
# USP7 1
# CEP72 1
# NRBF2 1
# VPS11 1
# DND1 1
# ACVR1 1
# AK2 1
# CFL1 1
# HSDL2 1
# PCMT1 1
# RPE 1
# UFM1 1
# VPS16 1
# CRKL 1
# MKNK2 1
# KIF2A 1
# DNAJC11 1
# Vps41 1
# Ppp6r1 1
# VPS8 1
# VPS33A 1
# ISOC2 1
# C15orf27 1
# ARFGAP1 1
# C7orf60 1
# CROCC 1
# PA2G4 1
# SND1 1
# ANXA5 1
# SNRPB2 1
# EIF5B 1
# GPI 1
# IDH2 1
# MRPL12 1
# CRNN 1
# ZNF207 1
# CPNE3 1
# CS 1
# CPSF6 1
# SRP68 1
# MYL12B 1
# CBS 1
# WDHD1 1
# HSP90B2P 1
# EIF4A1 1
# EEF1G 1
# RPS19 1
# RPL7A 1
# EIF2AK4 1
# COQ3 1
# GLRX 1
# LTA4H 1
# PRDX5 1
# PLS3 1

# %%
# sort nodes for the higest betweeness centrality
a2=nx.betweenness_centrality(U_whole)
a2_sorted= sorted(a2,key=a2.get, reverse=True)

for r in a2_sorted:
     print(r,a2[r])
# Out:
# NP_005339 0.4723494667086117
# NP_006588 0.27768797863429434
# AAH51814 0.22204659641291669
# ABB01006 0.16370876028154133
# NP_004574 0.08922140972907636
# EAW98517 0.08048996082810757
# CAG46507 0.0697424396227063
# NP_001737 0.06679477438923345
# AAW67757 0.06679477438923345
# BAD93042 0.06564739196995312
# CAI64497 0.061279196271432024
# EAW86495 0.03703195866450052
# APP 0.028927247306337955
# NP_006380 0.026263835979786314
# NTRK1 0.025164439798103833
# P43358 0.021552601348559876
# NP_037473 0.019901498915447215
# FN1 0.016552634273477012
# CDC73 0.014348215482287952
# FBXO6 0.014080979510562381
# CDK2 0.013772078846973599
# CUL7 0.012720282909015893
# CUL3 0.012568176972793022
# EAW53700 0.012093671551037502
# U2AF2 0.011130630226684564
# VCAM1 0.010850625295344528
# VCP 0.010649509163065961
# HDAC5 0.010190450974025357
# NXF1 0.009577539294223433
# FUS 0.00918334697401037
# STAU1 0.008962492557209229
# ITGA4 0.00764104463958829
# EGFR 0.007582416849989704
# CDH1 0.007426647680339699
# HUWE1 0.007048984550721716
# CDC5L 0.006942231856891192
# MCM2 0.006380110972691096
# CYLD 0.00636972563325876
# HNRNPA1 0.005961684010654931
# CFTR 0.005390501699109708
# SNW1 0.005329333771280593
# COPS5 0.005205013566842017
# Ksr1 0.005033754560493934
# ABL1 0.00492374228927814
# ESR1 0.0048145862656401
# CCDC8 0.0047518114583886455
# SLC9A1 0.00473735939888545
# UBL4A 0.004718606627775097
# ESRRB 0.004718606627775097
# UQCRC2 0.004702706316225541
# RAF1 0.004312655949770919
# CAND1 0.004275902597193222
# HSPA5 0.004174766820022358
# VDAC1 0.00417235614988874
# DLST 0.0039700237931378
# CUL2 0.0039089025838480234
# CUL1 0.0039089025838480234
# BRCA1 0.0038576833793929986
# TUBG1 0.0038576833793929986
# OBSL1 0.0036900677008626
# TP53 0.0036149761794179837
# ATF2 0.0035152574603946715
# HDAC6 0.0035148188843933696
# GBA 0.0033584924602128472
# RFWD3 0.0033584924602128472
# SOAT1 0.0033401337122006118
# UBC 0.003306456714355112
# LMAN1 0.0032349988713911535
# GAPDH 0.0032206591936901324
# DNAJA1 0.003034019053873922
# NEDD8 0.0030035022287421996
# LRRK2 0.0030035022287421996
# GRB2 0.0030035022287421996
# RAD52 0.0030035022287421996
# H2AFX 0.002993248464904123
# DLD 0.0029146724629769603
# MDM2 0.0028389899367538725
# XPO1 0.0027688931227870532
# ISG15 0.0027433274363089007
# PAN2 0.0027433274363089007
# CRY2 0.0027433274363089007
# ARRB2 0.0026854594882195814
# RPL7 0.0025786748936671012
# ILK 0.002538014395032825
# PSMD10 0.0025092419700381784
# ZBTB17 0.0025092419700381784
# PDIA3 0.002449179212491761
# LGALS3BP 0.0024008254839372476
# GAN 0.0024008254839372476
# EED 0.002378181947807337
# BAG3 0.002368513013329062
# HSPB1 0.002368513013329062
# TUBB 0.002368513013329062
# CD4 0.002291255621803512
# HSP90AB1 0.002291255621803512
# TRAF3IP1 0.0022752042441897035
# HSP90AA1 0.0022347449516828214
# PPP2R1A 0.0022347449516828214
# KCNH2 0.0022347449516828214
# ERBB3 0.0022347449516828214
# DDOST 0.002181444965704674
# MOV10 0.002150711288115105
# EEF1A1 0.002136274899931878
# PARD3 0.002114143899441226
# HSPA8 0.0021120492014405972
# ADRB2 0.0021073981919622507
# RAD21 0.0021033524360057555
# UBXN6 0.002093972638836406
# Mapk13 0.0020344118403405396
# RPA1 0.0020121879997835206
# RPA2 0.0020121879997835206
# RPA3 0.0020121879997835206
# STUB1 0.0020008573896160803
# HSPA4 0.0020008573896160803
# WWOX 0.0019413515796769243
# PARK2 0.0019399862316505855
# PSMA3 0.0019399862316505855
# CUL4A 0.0019399862316505855
# CUL5 0.0019329853790123707
# EPRS 0.0018648067336928093
# SOD1 0.0018643519797768209
# RAB1B 0.0018355276814411086
# LDHA 0.001807820703514429
# CAV1 0.001807820703514429
# RAD51 0.001807820703514429
# BBX 0.001807820703514429
# NOS2 0.0017440633714788012
# UNK 0.0017440633714788012
# MST1R 0.0016643968512904486
# CDK11B 0.0016643968512904486
# ARRB1 0.0016643968512904486
# AKT1 0.0016643968512904486
# BRAF 0.0016643968512904486
# CDKN1B 0.0016643968512904486
# TUBA1A 0.0016643968512904486
# LNX1 0.0016463324083627582
# GNAI2 0.0016463324083627582
# C1QBP 0.0016227641700266426
# env 0.0015583324092077661
# AI837181 0.0015557065670378446
# NR3C1 0.001550747534001108
# EWSR1 0.0015201466159065144
# MGMT 0.0014629802738499508
# NPM1 0.0014629802738499508
# PRKCD 0.0014629802738499508
# CANX 0.001457192366757729
# CSNK2A1 0.001457192366757729
# KIF1C 0.0014480762853721436
# PHB 0.0014471852581087153
# GANAB 0.0014343632652836973
# Bmpr1a 0.001430174159941909
# SIN3A 0.0013294136152261747
# AR 0.0013294136152261747
# CDK9 0.0013099667025144375
# ALDOA 0.0013099667025144375
# CDK4 0.001298000227410099
# CEP250 0.001298000227410099
# EBNA-LP 0.0012710802796297995
# EEF2 0.0012710802796297995
# HSPA1A 0.0012710802796297995
# METTL21B 0.0012710802796297995
# STIP1 0.0012710802796297995
# AURKA 0.0012710802796297995
# RPS6KB2 0.0012710802796297995
# AMBRA1 0.0012710802796297995
# C12orf10 0.0012710802796297995
# HSPA9 0.0012710802796297995
# PTEN 0.0012710802796297995
# AHSA1 0.0012710802796297995
# BCR 0.0012710802796297995
# RPS4X 0.0012541427353068854
# MAPK7 0.0012092929046851597
# ARAF 0.0012092929046851597
# YWHAE 0.0011766811540456612
# TUBB4B 0.0011700311071719273
# SNRPE 0.001142181606641122
# GRK5 0.001142181606641122
# PRMT5 0.001142181606641122
# FBXO25 0.001137853654905626
# RNF2 0.0011297202572040973
# RB1 0.0011276640866337813
# WNK1 0.0011168167767224403
# DNAJC7 0.001113445583198955
# NDRG1 0.0011038080878284008
# TUFM 0.0011038080878284008
# ATXN3 0.0011038080878284008
# SPTAN1 0.0011038080878284008
# PKM 0.001055114333332504
# DERL1 0.0010364757012130928
# SDHA 0.00102494941105632
# PTPRO 0.0010234352489656836
# GTF3C1 0.0010143233576494937
# CLU 0.0009927143783047573
# DNAJB4 0.0009757588452319529
# P4HB 0.0009631578364808476
# FANCC 0.0009495684410986423
# CUL4B 0.0009495684410986423
# COPS6 0.0009495684410986423
# KCNQ4 0.0009495684410986423
# IQCB1 0.0009495684410986423
# FANCA 0.0009495684410986423
# RBSN 0.0009446125989527383
# PTRF 0.0009446125989527383
# SF3A2 0.0009226037583201809
# PPME1 0.0008845905454129145
# BCAR1 0.0008431746605682539
# SKI 0.0007887365826895589
# TERF1 0.0007797213153891179
# SENP3 0.0007797213153891179
# BARD1 0.0007709115853047068
# NEK9 0.0007210903221283834
# ASB2 0.0007210903221283834
# IKBKB 0.0007210903221283834
# TYK2 0.0007210903221283834
# BIRC5 0.0007210903221283834
# ACTG1 0.0007210903221283834
# PSMB5 0.0007210903221283834
# XRCC1 0.0007210903221283834
# SUZ12 0.0007057117522400488
# MTNR1A 0.0007053610057929379
# COPB1 0.0007053610057929379
# PTPRA 0.0007053610057929379
# TECR 0.0007025209928929731
# PTGIR 0.0007025209928929731
# FAM187B 0.0007025209928929731
# SERPINA1 0.0007025209928929731
# IRS4 0.0007025082248490952
# PAK1 0.0007025082248490952
# PRKCZ 0.0007025082248490952
# PRKAA1 0.0007025082248490952
# PRKCI 0.0007025082248490952
# TERT 0.0007025082248490952
# CDC25C 0.0007025082248490952
# CLK3 0.0007025082248490952
# NSL1 0.0007025082248490952
# TAB2 0.0007025082248490952
# PRR14L 0.0007025082248490952
# PGK1 0.0007025082248490952
# MYH9 0.0007025082248490952
# TNK1 0.0007025082248490952
# MAP2K5 0.0007025082248490952
# SGK1 0.0007025082248490952
# MAP3K2 0.0007025082248490952
# FBXW11 0.0007025082248490952
# BTRC 0.0007025082248490952
# TRIM32 0.0007025082248490952
# TNFAIP3 0.0007025082248490952
# MDM4 0.0007025082248490952
# RPS6KA5 0.0007025082248490952
# STK38 0.0007025082248490952
# PRKCE 0.0007025082248490952
# PRKCA 0.0007025082248490952
# LIMK1 0.0007025082248490952
# MAP3K5 0.0007025082248490952
# PRKD1 0.0007025082248490952
# PAK6 0.0007025082248490952
# HSPA1B 0.0007025082248490952
# ATP5A1 0.0007025082248490952
# DNAJC3 0.0006919504386615993
# DNAJC2 0.0006919504386615993
# ATL3 0.000678591028143029
# RAB1A 0.000678591028143029
# RAB2A 0.000678591028143029
# AMFR 0.0006773454284381699
# RPN1 0.0006575298460758191
# IPO9 0.0006445651148502495
# KPNA4 0.0006445651148502495
# LDHB 0.0006169244067363071
# RMDN3 0.0006169244067363071
# DNAJC9 0.0006114294692330821
# FAF2 0.0006106469855186947
# COX15 0.0005744893495234065
# BCAP31 0.0005689712760651175
# VDAC2 0.0005581165664762173
# ALK 0.0005451125906018589
# MYC 0.0005451125906018589
# SIRT1 0.0005451125906018589
# HSPE1 0.0005451125906018589
# ASB4 0.0005451125906018589
# AURKB 0.0005451125906018589
# FBXO17 0.0005451125906018589
# PRDM1 0.0005451125906018589
# POT1 0.0005449300383977871
# IQGAP1 0.0005444674172535923
# SIRT7 0.0005387800718184098
# MAPT 0.0005334711682354452
# RFWD2 0.0005334711682354452
# UBE3A 0.0005334711682354452
# YWHAQ 0.0005334711682354452
# MAPK8 0.0005334711682354452
# CBL 0.0005334711682354452
# GCH1 0.0005334711682354452
# CTNNB1 0.0005334711682354452
# MAP2K1 0.0005334711682354452
# SYNPO2 0.0005334711682354452
# ERRFI1 0.0005334711682354452
# NFATC2 0.0005334711682354452
# CSNK1D 0.0005334711682354452
# EP300 0.0005334711682354452
# TGM2 0.0005334711682354452
# HNRNPH1 0.0005159917183380142
# ATP6V1A 0.0005159917183380142
# NOS1AP 0.0005159917183380142
# YWHAZ 0.0005124115338092883
# OLA1 0.0005124115338092883
# FKBP5 0.0005046916768093433
# TGFBR1 0.0005046916768093433
# TGFBR2 0.0005046916768093433
# PRKACB 0.0005046916768093433
# CDK5 0.0005046916768093433
# UBE2N 0.0005046916768093433
# NANS 0.0005046916768093433
# TPM3 0.0005046916768093433
# VPS18 0.0005046916768093433
# VPS41 0.0005046916768093433
# MAGED2 0.0005046916768093433
# SOX2 0.0004966115313417128
# MYOD1 0.0004714936701458233
# SKP2 0.0004714936701458233
# EPAS1 0.0004714936701458233
# ATP5B 0.0004714936701458233
# ACTN1 0.0004714936701458233
# SLC25A5 0.0004714936701458233
# SSR3 0.0004714936701458233
# rev 0.00046742268864707686
# Ranbp2 0.00046661221327993455
# EIF4A3 0.00046661221327993455
# MAGOH 0.00046661221327993455
# IPO7 0.00046661221327993455
# SON 0.00046661221327993455
# HERC5 0.00046661221327993455
# PAK4 0.0004479929038567533
# KIAA1377 0.0004479929038567533
# TRA2B 0.0004479929038567533
# IKBKE 0.00044656871397128357
# HK2 0.00044656871397128357
# LGR4 0.00044649645713184936
# ITGB1 0.00044649645713184936
# PPID 0.00042841745820588263
# HCFC1 0.00042841745820588263
# P2rx7 0.00042841745820588263
# DNAJA3 0.00042841745820588263
# JAK2 0.00042841745820588263
# BAG2 0.00042841745820588263
# BAG4 0.00042841745820588263
# HSF1 0.00042841745820588263
# TSSK6 0.00042841745820588263
# HIST3H3 0.00042841745820588263
# FGFR3 0.00042841745820588263
# USP50 0.00042841745820588263
# AGO4 0.00042841745820588263
# DYRK2 0.00042841745820588263
# HLA-DRA 0.00042841745820588263
# HLA-DRB1 0.00042841745820588263
# HLA-DRB3 0.00042841745820588263
# HLA-DRB4 0.00042841745820588263
# HLA-DRB5 0.00042841745820588263
# VHL 0.00042841745820588263
# MKKS 0.00042841745820588263
# UCHL1 0.00042841745820588263
# SNCA 0.00042841745820588263
# DCUN1D1 0.00042841745820588263
# MCL1 0.00042841745820588263
# SGTA 0.00042841745820588263
# AIPL1 0.00042841745820588263
# UBASH3B 0.00042841745820588263
# SHC1 0.00042841745820588263
# IRAK1 0.00042841745820588263
# HSPA2 0.00042841745820588263
# SUGT1 0.00042841745820588263
# ESR2 0.00042841745820588263
# PPP5C 0.00042841745820588263
# CAMKMT 0.00042841745820588263
# METTL22 0.00042841745820588263
# SLC12A3 0.00042841745820588263
# ST13 0.00042841745820588263
# HIF1A 0.00042841745820588263
# JUN 0.00042841745820588263
# TARDBP 0.00042841745820588263
# CDKN2A 0.00042841745820588263
# HSPA6 0.00042841745820588263
# RPS6KA3 0.00042841745820588263
# CDKN1A 0.00042841745820588263
# MCF2 0.00042841745820588263
# TSSK1B 0.00042841745820588263
# CCDC117 0.00042841745820588263
# DNAJA2 0.00042841745820588263
# RPLP0 0.00042841745820588263
# NPHP4 0.00042841745820588263
# Bag2 0.00042841745820588263
# MCM5 0.00042841745820588263
# KCNA5 0.00042841745820588263
# CDC37 0.00042841745820588263
# KLHL34 0.00042841745820588263
# NOX5 0.00042841745820588263
# KLHL10 0.00042841745820588263
# DET1 0.00042841745820588263
# KLHL36 0.00042841745820588263
# THAP4 0.00042841745820588263
# KBTBD4 0.00042841745820588263
# CDK3 0.00042841745820588263
# DDX59 0.00042841745820588263
# PRKDC 0.00042841745820588263
# SSBP1 0.00042841745820588263
# RPS15A 0.00042841745820588263
# NLRP12 0.00042841745820588263
# TTC1 0.00042841745820588263
# HSPH1 0.00042841745820588263
# EDRF1 0.00042841745820588263
# TAB1 0.00042841745820588263
# SP1 0.00042841745820588263
# RAB7A 0.0004266165252624146
# SMARCA4 0.0004266165252624146
# AGO2 0.0004215841807011583
# PCBP1 0.0004215841807011583
# MTHFD1 0.0004215841807011583
# HIPK4 0.0004215841807011583
# MAPK4 0.0004215841807011583
# GOLT1B 0.0004189989716031214
# RAB5A 0.00039590140701111247
# ELAVL1 0.00039435348668072346
# KPNA2 0.00039435348668072346
# ETFA 0.0003650559951822343
# PSMC2 0.0003650559951822343
# CHMP4B 0.0003650559951822343
# TNFRSF1A 0.000364891092394894
# HGS 0.000364891092394894
# SF3A1 0.000364891092394894
# VAMP2 0.000364891092394894
# DUT 0.000364891092394894
# SF3A3 0.000364891092394894
# FAN1 0.0003648004412101576
# ECHS1 0.0003648004412101576
# COQ2 0.0003648004412101576
# PARK7 0.0003648004412101576
# SPRTN 0.00035423160695516857
# RIC3 0.00035423160695516857
# CAPZA1 0.00035423160695516857
# HSD17B10 0.00034354319458180133
# CLTC 0.00033585451822386477
# COX2 0.00033585451822386477
# PAX6 0.00032095648372801295
# BCL6 0.0003152693411273902
# HMGA1 0.0003152693411273902
# RPAP1 0.0002975502308220506
# PACSIN2 0.0002975502308220506
# PACSIN3 0.0002975502308220506
# ERG 0.0002975502308220506
# HSPD1 0.0002975502308220506
# SMURF1 0.0002975502308220506
# CCAR2 0.0002975502308220506
# METTL20 0.0002975502308220506
# CDC20 0.0002975502308220506
# TUBGCP3 0.0002975502308220506
# LRRC28 0.0002975502308220506
# HYPK 0.0002975502308220506
# ALOXE3 0.0002975502308220506
# FOXRED1 0.0002975502308220506
# NCOR1 0.0002889783788550378
# YWHAB 0.0002889783788550378
# ARFIP1 0.0002878520159985943
# HIST1H3E 0.00028454462127086566
# CEP170P1 0.00028454462127086566
# RC3H1 0.00028454462127086566
# EIF2AK3 0.0002702902767510056
# TERF2 0.0002702902767510056
# POLR2E 0.0002702902767510056
# CCT2 0.0002702902767510056
# LYN 0.0002702902767510056
# BLK 0.0002702902767510056
# LIMK2 0.0002702902767510056
# IKBKG 0.0002702902767510056
# APAF1 0.0002702902767510056
# CSNK2A2 0.0002702902767510056
# ERBB2 0.0002702902767510056
# CAP1 0.0002702902767510056
# CDC37L1 0.0002702902767510056
# MCM3 0.0002702902767510056
# SMG1 0.0002702902767510056
# STAT3 0.0002702902767510056
# PDHA1 0.00026763143644416846
# COX6B1 0.00026763143644416846
# TCTN2 0.00024252374247160728
# TCTN3 0.00024252374247160728
# TCTN1 0.00024252374247160728
# Itgb1 0.00024252374247160728
# PTPRN 0.00024252374247160728
# DNAJB1 0.00023845941102178855
# DNAJB11 0.00023845941102178855
# HYOU1 0.00023845941102178855
# DNAJA4 0.00023845941102178855
# DNM1L 0.0002364944030850611
# SMARCC1 0.00020937984871525047
# YAP1 0.0002038282659747271
# XRCC6 0.0002038282659747271
# GBAS 0.00020333433586891756
# HDAC1 0.0001944500650726751
# ICT1 0.0001944500650726751
# KRAS 0.0001944500650726751
# NDUFA7 0.00017884292720967972
# CYC1 0.00017453022985180477
# YIPF3 0.00017453022985180477
# ATP6V1B2 0.00016158354422043822
# DNAJC17 0.00015594079681776035
# TMPO 0.00015430388574796535
# HDGF 0.00015128801244600887
# PUF60 0.0001500649886122598
# MAPK6 0.0001477549691279876
# SIRT3 0.0001477549691279876
# XRCC3 0.0001477549691279876
# RAB5C 0.0001390063903534379
# Rab5c 0.0001390063903534379
# RAB11A 0.0001390063903534379
# VAPA 0.0001390063903534379
# PTPN1 0.0001390063903534379
# PHB2 0.0001390063903534379
# STOML2 0.0001390063903534379
# YIPF5 0.0001390063903534379
# SMARCA2 0.00013682962295196756
# tat 0.00013682962295196756
# IPO11 0.00013682962295196756
# PYGL 0.0001288384758220029
# MAPRE1 0.0001244040406646228
# SNRPF 0.0001244040406646228
# AIMP1 0.00011383416870946642
# EXT2 0.00010505011769315792
# DNAJC8 0.00010505011769315792
# ALDOC 9.005659976663182e-05
# ASNS 9.005659976663182e-05
# HSP90B1 8.309558942277943e-05
# APOB 8.309558942277943e-05
# CALR 8.309558942277943e-05
# LDLR 8.309558942277943e-05
# ERLIN2 8.309558942277943e-05
# CCT3 8.309558942277943e-05
# KPNA3 8.309558942277943e-05
# RCN1 8.309558942277943e-05
# RPN2 8.309558942277943e-05
# SLC25A3 8.309558942277943e-05
# SLC33A1 8.309558942277943e-05
# GABRA1 8.309558942277943e-05
# PRKCSH 8.309558942277943e-05
# ACADM 8.309558942277943e-05
# HSD17B12 7.823028619372702e-05
# Lima1 7.823028619372702e-05
# ZNF746 7.823028619372702e-05
# OS9 4.5182175850805436e-05
# SEL1L 4.5182175850805436e-05
# LRP1 1.5872444465015132e-09
# PIGK 1.5872444465015132e-09
# LCT 1.5872444465015132e-09
# CD1D 1.5872444465015132e-09
# EBI3 1.5872444465015132e-09
# CD3D 1.5872444465015132e-09
# F8 1.5872444465015132e-09
# SLC6A4 1.5872444465015132e-09
# SLC2A1 1.5872444465015132e-09
# SLC4A1 1.5872444465015132e-09
# SVIP 1.5872444465015132e-09
# BSCL2 1.5872444465015132e-09
# ZNRF4 1.5872444465015132e-09
# Tor1aip1 1.5872444465015132e-09
# L1CAM 1.5872444465015132e-09
# TCF3 1.5872444465015132e-09
# UBXN4 1.5872444465015132e-09
# POMP 1.5872444465015132e-09
# EDEM1 1.5872444465015132e-09
# OPRD1 1.5872444465015132e-09
# LPA 1.5872444465015132e-09
# TOR1A 1.5872444465015132e-09
# PKD2 1.5872444465015132e-09
# PGRMC1 1.5872444465015132e-09
# SMURF2 1.5872444465015132e-09
# CLN5 1.5872444465015132e-09
# NPHS1 1.5872444465015132e-09
# TRAF6 1.5872444465015132e-09
# PMP22 1.5872444465015132e-09
# BMI1 1.5872444465015132e-09
# FOXRED2 1.5872444465015132e-09
# EMC1 1.5872444465015132e-09
# PPT1 1.5872444465015132e-09
# OGFOD3 1.5872444465015132e-09
# POMK 1.5872444465015132e-09
# POGLUT1 1.5872444465015132e-09
# WNT3A 1.5872444465015132e-09
# CHST8 1.5872444465015132e-09
# PLTP 1.5872444465015132e-09
# CHST9 1.5872444465015132e-09
# APMAP 1.5872444465015132e-09
# ATP1B1 1.5872444465015132e-09
# ATP2B1 1.5872444465015132e-09
# ATP2B3 1.5872444465015132e-09
# ATP2B4 1.5872444465015132e-09
# CCT4 1.5872444465015132e-09
# DARS 1.5872444465015132e-09
# PDIA6 1.5872444465015132e-09
# PTBP1 1.5872444465015132e-09
# RPS5 1.5872444465015132e-09
# SEC61B 1.5872444465015132e-09
# LNPEP 1.5872444465015132e-09
# CHST15 1.5872444465015132e-09
# Prkacb 1.5872444465015132e-09
# Ncstn 1.5872444465015132e-09
# Spire2 1.5872444465015132e-09
# EDEM2 1.5872444465015132e-09
# TMEM258 1.5872444465015132e-09
# ACP5 1.5872444465015132e-09
# CD1E 1.5872444465015132e-09
# P2RX2 1.5872444465015132e-09
# CLEC2D 1.5872444465015132e-09
# BRINP2 1.5872444465015132e-09
# GXYLT1 1.5872444465015132e-09
# NRROS 1.5872444465015132e-09
# CHST6 1.5872444465015132e-09
# TMEM5 1.5872444465015132e-09
# LIPG 1.5872444465015132e-09
# HYAL3 1.5872444465015132e-09
# ADAM21 1.5872444465015132e-09
# UST 1.5872444465015132e-09
# CD1B 1.5872444465015132e-09
# DPEP3 1.5872444465015132e-09
# DNASE2 1.5872444465015132e-09
# GABRG2 1.5872444465015132e-09
# ADAM30 1.5872444465015132e-09
# P2RX5 1.5872444465015132e-09
# TMPRSS11B 1.5872444465015132e-09
# AMIGO3 1.5872444465015132e-09
# IL27RA 1.5872444465015132e-09
# MPPE1 1.5872444465015132e-09
# CPA5 1.5872444465015132e-09
# DCT 1.5872444465015132e-09
# ST3GAL2 1.5872444465015132e-09
# WNT16 1.5872444465015132e-09
# OPCML 1.5872444465015132e-09
# GAL3ST1 1.5872444465015132e-09
# FUCA2 1.5872444465015132e-09
# C12orf49 1.5872444465015132e-09
# NCEH1 1.5872444465015132e-09
# SMPD1 1.5872444465015132e-09
# B3GNT3 1.5872444465015132e-09
# CCNJL 1.5872444465015132e-09
# AGT 1.5872444465015132e-09
# ARSG 1.5872444465015132e-09
# FUT9 1.5872444465015132e-09
# TOR3A 1.5872444465015132e-09
# A4GALT 1.5872444465015132e-09
# IGSF6 1.5872444465015132e-09
# TRHDE 1.5872444465015132e-09
# GPR114 1.5872444465015132e-09
# TMPRSS3 1.5872444465015132e-09
# SERPINA5 1.5872444465015132e-09
# SCNN1D 1.5872444465015132e-09
# CHST14 1.5872444465015132e-09
# TMED6 1.5872444465015132e-09
# WNT7A 1.5872444465015132e-09
# ST8SIA3 1.5872444465015132e-09
# PTPRE 1.5872444465015132e-09
# MTNR1B 1.5872444465015132e-09
# TF 1.5872444465015132e-09
# TSHR 1.5872444465015132e-09
# Edem1 1.5872444465015132e-09
# CHRNA5 1.5872444465015132e-09
# SERPINF2 1.5872444465015132e-09
# ASGR1 1.5872444465015132e-09
# ABCC1 1.5872444465015132e-09
# ABCC3 1.5872444465015132e-09
# ATP13A1 1.5872444465015132e-09
# CCT6A 1.5872444465015132e-09
# IDH3A 1.5872444465015132e-09
# KDSR 1.5872444465015132e-09
# MOGS 1.5872444465015132e-09
# NCLN 1.5872444465015132e-09
# PC 1.5872444465015132e-09
# GGT1 1.5872444465015132e-09
# OSGEP 0.0
# DSTYK 0.0
# SGSM3 0.0
# TBC1D15 0.0
# TBC1D17 0.0
# FLOT1 0.0
# LAMTOR3 0.0
# ZMPSTE24 0.0
# ATP4A 0.0
# LGALS1 0.0
# RAB10 0.0
# RAB11B 0.0
# RAP1A 0.0
# RAP1B 0.0
# GDI1 0.0
# LIMA1 0.0
# Actb 0.0
# Rab5b 0.0
# Kctd5 0.0
# Flnb 0.0
# DUSP22 0.0
# DUSP8 0.0
# DUSP9 0.0
# SUN2 0.0
# EEA1 0.0
# APPL2 0.0
# ARF1 0.0
# ARL8A 0.0
# LDHAL6A 0.0
# LDHAL6B 0.0
# RAB8A 0.0
# RAB8B 0.0
# ATP6V0A1 0.0
# CLCN7 0.0
# COX5B 0.0
# FLOT2 0.0
# H3F3A 0.0
# IGF2R 0.0
# NDUFB7 0.0
# NDUFS1 0.0
# NDUFS5 0.0
# CHMP1A 0.0
# PPIA 0.0
# SS18 0.0
# TFRC 0.0
# TTC3 0.0
# STX7 0.0
# GPRC5A 0.0
# ATP6V0D1 0.0
# XPR1 0.0
# COPS2 0.0
# GOSR1 0.0
# CLINT1 0.0
# PIEZO1 0.0
# IST1 0.0
# C2CD5 0.0
# CKAP4 0.0
# TMED10 0.0
# IMMT 0.0
# RASSF8 0.0
# KDM2A 0.0
# WDFY3 0.0
# SCFD1 0.0
# HAUS5 0.0
# GLTSCR1L 0.0
# GCA 0.0
# LETMD1 0.0
# CHMP2B 0.0
# MYOF 0.0
# ATP2C1 0.0
# CHMP2A 0.0
# ABT1 0.0
# NDUFB11 0.0
# CHCHD3 0.0
# OCIAD1 0.0
# IMPACT 0.0
# TTC17 0.0
# MUC13 0.0
# KIDINS220 0.0
# SUGP1 0.0
# MRPS14 0.0
# SLC35E1 0.0
# ZCRB1 0.0
# GADD45GIP1 0.0
# ACBD5 0.0
# SLC38A5 0.0
# PRKCDBP 0.0
# LRR1 0.0
# MRPL55 0.0
# MITD1 0.0
# RAB43 0.0
# CHM 0.0
# GNAT3 0.0
# CHML 0.0
# GDI2 0.0
# DLG4 0.0
# FZD4 0.0
# MRGPRX1 0.0
# LPAR3 0.0
# NDP 0.0
# OXER1 0.0
# BAG6 0.0
# ZNRF3 0.0
# LGR6 0.0
# GNAQ 0.0
# GNB1 0.0
# GNG2 0.0
# Dvl3 0.0
# PDZRN3 0.0
# E2F1 0.0
# RBL1 0.0
# RBL2 0.0
# BRE 0.0
# CLN3 0.0
# SYNCRIP 0.0
# PARP1 0.0
# AFG3L2 0.0
# ATP1A1 0.0
# ATP5L 0.0
# COX4I1 0.0
# GOSR2 0.0
# MTCH2 0.0
# NDUFB4 0.0
# SCAMP2 0.0
# SSR1 0.0
# TAGLN2 0.0
# TPD52 0.0
# UQCRQ 0.0
# VDAC3 0.0
# FAP 0.0
# MED20 0.0
# MED23 0.0
# AKAP1 0.0
# EMC2 0.0
# MTX2 0.0
# FGFR1OP2 0.0
# TMEM63B 0.0
# MMGT1 0.0
# Atp2a2 0.0
# C1qbp 0.0
# Eef1a1 0.0
# Aifm1 0.0
# Mtx2 0.0
# Rab11a 0.0
# Tmed2 0.0
# Rmdn3 0.0
# Tmem109 0.0
# NF2 0.0
# ARMC7 0.0
# TPTE 0.0
# ANXA2 0.0
# COL9A2 0.0
# IGHG1 0.0
# ACTB 0.0
# LMNA 0.0
# SMG5 0.0
# PLEC 0.0
# RAPH1 0.0
# DBN1 0.0
# LONRF3 0.0
# COX6C 0.0
# NAP1L1 0.0
# BCAP29 0.0
# BCAS3 0.0
# CASC3 0.0
# CCL5 0.0
# ST14 0.0
# C11orf73 0.0
# STOM 0.0
# RAN 0.0
# YRB1 0.0
# DIS3 0.0
# NUTF2 0.0
# XPO6 0.0
# SMARCB1 0.0
# NUP153 0.0
# RANGRF 0.0
# RCC1 0.0
# RANBP1 0.0
# RANBP2 0.0
# RANBP10 0.0
# KPNB1 0.0
# RANBP9 0.0
# XPO5 0.0
# RANBP3 0.0
# IPO5 0.0
# rna1 0.0
# RANGAP1 0.0
# SNUPN 0.0
# NTF2A 0.0
# NTF2B 0.0
# H2AFY 0.0
# SLX1B 0.0
# TAF6 0.0
# Nup88 0.0
# Csnk1e 0.0
# Nup188 0.0
# IPO13 0.0
# UL27 0.0
# RAPGEF3 0.0
# TFAP4 0.0
# MAD2L2 0.0
# Nutf2 0.0
# Nxt1 0.0
# SF3B6 0.0
# EXOSC2 0.0
# PTMA 0.0
# ASB16 0.0
# MSL1 0.0
# NUPR1 0.0
# CSE1L 0.0
# EIF3I 0.0
# KPNA1 0.0
# KPNA6 0.0
# PSMA4 0.0
# SKIV2L 0.0
# TNPO1 0.0
# KMT2A 0.0
# UBE2I 0.0
# KIF3A 0.0
# CCDC88A 0.0
# NUP107 0.0
# Ranbp1 0.0
# Ube2i 0.0
# Immt 0.0
# Rcc1 0.0
# Nup107 0.0
# Nup98 0.0
# EIF2S2 0.0
# CRM1 0.0
# AKIRIN2 0.0
# XPOT 0.0
# TNPO2 0.0
# XPO7 0.0
# XPO4 0.0
# TPR 0.0
# RBM39 0.0
# U2AF1 0.0
# RGPD5 0.0
# PFDN4 0.0
# Rangap1 0.0
# AGL 0.0
# EIF6 0.0
# KPNA5 0.0
# RANBP6 0.0
# RGPD2 0.0
# RGPD8 0.0
# TMEM194B 0.0
# DLGAP5 0.0
# CDCA2 0.0
# TMEM194A 0.0
# NUP214 0.0
# AKIRIN1 0.0
# NUP62 0.0
# IKBIP 0.0
# BAG1 0.0
# TCERG1 0.0
# PPP1R15A 0.0
# HDAC3 0.0
# CITED1 0.0
# HSPBP1 0.0
# TADA3 0.0
# RGS2 0.0
# RBX1 0.0
# CYCS 0.0
# POLR3D 0.0
# STMN1 0.0
# GOT2 0.0
# GPR37 0.0
# HNRNPD 0.0
# RUVBL1 0.0
# GPN1 0.0
# PACSIN1 0.0
# HDAC10 0.0
# CCND1 0.0
# MEN1 0.0
# IL16 0.0
# CENPA 0.0
# WDR82 0.0
# CDK5RAP3 0.0
# LALBA 0.0
# CLTA 0.0
# DGCR8 0.0
# MME 0.0
# TLR4 0.0
# TLR9 0.0
# INSIG2 0.0
# HMGB1 0.0
# Psma2 0.0
# lqf 0.0
# clint1-a 0.0
# ATXN1 0.0
# DNAJB2 0.0
# PPP1CC 0.0
# PPP1CA 0.0
# PSMA2 0.0
# FAF1 0.0
# KCND3 0.0
# BCAS2 0.0
# CWC15 0.0
# HTT 0.0
# CAPZB 0.0
# DNAJB14 0.0
# INPPL1 0.0
# PIK3R2 0.0
# CRK 0.0
# EPS15 0.0
# AP2M1 0.0
# ATP13A2 0.0
# RAD23A 0.0
# Bax 0.0
# DNAJB12 0.0
# SRRT 0.0
# METTL21A 0.0
# METTL21C 0.0
# LAMP2 0.0
# HLTF 0.0
# TOPBP1 0.0
# RELA 0.0
# ATXN10 0.0
# NAPRT 0.0
# SHFM1 0.0
# ZBTB1 0.0
# TRIM5 0.0
# IVNS1ABP 0.0
# AIRE 0.0
# HAUS1 0.0
# HAUS2 0.0
# TUBGCP2 0.0
# TUBGCP4 0.0
# IL32 0.0
# C17orf49 0.0
# SUMO2 0.0
# SIRT6 0.0
# CCNI2 0.0
# DRG2 0.0
# LPGAT1 0.0
# POC1A 0.0
# VASH1 0.0
# EBNA1BP2 0.0
# FAM189B 0.0
# KIAA1191 0.0
# NXF5 0.0
# USP46 0.0
# VSX1 0.0
# ZSCAN32 0.0
# WDR37 0.0
# APBB2 0.0
# NDRG2 0.0
# KCNJ10 0.0
# DENND2D 0.0
# CYP3A4 0.0
# KNSTRN 0.0
# CAD 0.0
# CPS1 0.0
# GRPEL1 0.0
# PABPC1 0.0
# ATM 0.0
# AKAP5 0.0
# LRPPRC 0.0
# KIAA1107 0.0
# SDHAF2 0.0
# CDCA5 0.0
# Tgfbr1 0.0
# ID2 0.0
# HEMGN 0.0
# ALKBH3 0.0
# HTN3 0.0
# OTUB1 0.0
# NANOG 0.0
# POU5F1 0.0
# ZNF618 0.0
# PHF8 0.0
# RFX1 0.0
# HSF2 0.0
# ARMC1 0.0
# PDPK1 0.0
# TBC1D23 0.0
# GMNN 0.0
# HMCES 0.0
# FLYWCH2 0.0
# CYP8B1 0.0
# SNX20 0.0
# ABHD15 0.0
# KCND2 0.0
# VILL 0.0
# SLC27A3 0.0
# TCAP 0.0
# DGCR14 0.0
# GNA15 0.0
# C21orf59 0.0
# NUS1 0.0
# CSNK1E 0.0
# FAM73B 0.0
# FUZ 0.0
# DCDC2B 0.0
# VWA2 0.0
# PRODH 0.0
# CDK10 0.0
# TRIM16L 0.0
# ARNT 0.0
# CNN2 0.0
# RNF34 0.0
# GFAP 0.0
# C19orf45 0.0
# HCFC2 0.0
# SPATA5L1 0.0
# TRMT12 0.0
# CAPG 0.0
# LRRC56 0.0
# NMNAT3 0.0
# VSIG8 0.0
# TYSND1 0.0
# SSMEM1 0.0
# THSD4 0.0
# TTC30B 0.0
# KCNV2 0.0
# DSCR4 0.0
# SETMAR 0.0
# ZNF488 0.0
# VANGL2 0.0
# EPB42 0.0
# LEPREL2 0.0
# HAO2 0.0
# BPNT1 0.0
# FRMD8P1 0.0
# PRKACG 0.0
# CHD1L 0.0
# AGPAT3 0.0
# NPAS1 0.0
# DHX57 0.0
# CPLX4 0.0
# GPR6 0.0
# PNPLA5 0.0
# KCNC4 0.0
# PANK2 0.0
# NLRX1 0.0
# IER2 0.0
# CFAP52 0.0
# HTR1E 0.0
# BBS1 0.0
# POLE 0.0
# PPEF1 0.0
# C9orf116 0.0
# EXOC3L2 0.0
# C1orf94 0.0
# SSH3 0.0
# F12 0.0
# GK2 0.0
# TAF6L 0.0
# DOCK5 0.0
# FCRL3 0.0
# C20orf96 0.0
# TSPYL6 0.0
# MVP 0.0
# IL17RC 0.0
# ARHGEF16 0.0
# CHI3L1 0.0
# CDKL3 0.0
# MPZL1 0.0
# RCCD1 0.0
# GLIPR1 0.0
# NOA1 0.0
# TM4SF1 0.0
# ERH 0.0
# FBP1 0.0
# PPP1R12B 0.0
# RNPS1 0.0
# HNRNPA3 0.0
# SAMM50 0.0
# SEC24C 0.0
# RPL18A 0.0
# NECAP2 0.0
# RPL8 0.0
# SEC31A 0.0
# POU2F1 0.0
# ASNA1 0.0
# TUBA4B 0.0
# YARS 0.0
# DNAJB6 0.0
# GABRB1 0.0
# HSPA4L 0.0
# AMT 0.0
# NMI 0.0
# TRIM38 0.0
# APOA1BP 0.0
# DNAJC1 0.0
# DNAJC13 0.0
# FDPS 0.0
# LMNB1 0.0
# NACA 0.0
# RPL13A 0.0
# RNF207 0.0
# CD207 0.0
# ABL2 0.0
# GAK 0.0
# HIST2H3PS2 0.0
# RPRD2 0.0
# TBCE 0.0
# C6orf106 0.0
# SRP54 0.0
# TACC3 0.0
# MAPRE2 0.0
# ZNF703 0.0
# KCTD15 0.0
# HBB 0.0
# HBA2 0.0
# HDLBP 0.0
# HIST1H1B 0.0
# NFS1 0.0
# MAP2K2 0.0
# QRICH1 0.0
# ENDOG 0.0
# CKAP5 0.0
# PPP1R8 0.0
# MAVS 0.0
# RNF25 0.0
# MAD1L1 0.0
# FOXC1 0.0
# ATF1 0.0
# CSTF3 0.0
# ALB 0.0
# CYB5R3 0.0
# CSDE1 0.0
# MYB 0.0
# CREBBP 0.0
# DHFR 0.0
# CA2 0.0
# CASP3 0.0
# ALDH2 0.0
# SRRM2 0.0
# PPP2R2C 0.0
# SPG20 0.0
# PCK1 0.0
# ASB9 0.0
# HSPA14 0.0
# PAXIP1 0.0
# HCVgp1 0.0
# PLG 0.0
# CLEC7A 0.0
# DDX39B 0.0
# EIF4E 0.0
# EIF5A 0.0
# GDA 0.0
# GSR 0.0
# MAPK14 0.0
# NAGK 0.0
# OXCT1 0.0
# PTMS 0.0
# C11orf58 0.0
# SMS 0.0
# THOP1 0.0
# TRIM63 0.0
# NFAM1 0.0
# SLC25A41 0.0
# ATP5F1 0.0
# TAZ 0.0
# DCAF5 0.0
# MRPL4 0.0
# OXNAD1 0.0
# SIRT4 0.0
# QTRT1 0.0
# MRPL37 0.0
# TTC39B 0.0
# THBS3 0.0
# KIAA0101 0.0
# KIF2C 0.0
# PREP 0.0
# REXO2 0.0
# SCARNA22 0.0
# PLCG2 0.0
# DDB2 0.0
# LAMB3 0.0
# PCK2 0.0
# NIPSNAP1 0.0
# HMG20A 0.0
# FBXO7 0.0
# BCOR 0.0
# CDKN2AIP 0.0
# DCLRE1B 0.0
# TUBA1C 0.0
# Gnb1 0.0
# Hax1 0.0
# Ska1 0.0
# Cdkn2aip 0.0
# Ckap5 0.0
# Wdr5 0.0
# Sept9 0.0
# FOXL1 0.0
# DEFA5 0.0
# ASIC4 0.0
# GTPBP8 0.0
# DCAF4 0.0
# RELL2 0.0
# GORASP1 0.0
# C4orf29 0.0
# TFB1M 0.0
# NDUFS7 0.0
# RPUSD3 0.0
# TRIM43 0.0
# RASL10B 0.0
# BCAT2 0.0
# CYB5A 0.0
# TRIB2 0.0
# HARS2 0.0
# MTG2 0.0
# METTL17 0.0
# SET 0.0
# MRPS30 0.0
# TRUB2 0.0
# GPX7 0.0
# XAGE1B 0.0
# NEU4 0.0
# KLHL33 0.0
# YBEY 0.0
# SLC25A43 0.0
# PRAMEF17 0.0
# TRIM35 0.0
# FBXO15 0.0
# BPHL 0.0
# SNRNP27 0.0
# GMFG 0.0
# GSTK1 0.0
# YARS2 0.0
# MRPL16 0.0
# OXCT2 0.0
# GLB1L3 0.0
# METTL8 0.0
# IDH3G 0.0
# PDK3 0.0
# DKK3 0.0
# HIST2H2BE 0.0
# BAK1 0.0
# BAX 0.0
# HNRNPA2B1 0.0
# DDX17 0.0
# EEF1B2 0.0
# HEXIM1 0.0
# SEPT9 0.0
# CXorf56 0.0
# MCCC2 0.0
# SCARB2 0.0
# SAP30BP 0.0
# UBR4 0.0
# FTL 0.0
# NCAPD2 0.0
# PTPN2 0.0
# COLGALT1 0.0
# RAB5B 0.0
# GID8 0.0
# PAF1 0.0
# STRN4 0.0
# LAMB1 0.0
# PPA1 0.0
# PLOD3 0.0
# SARNP 0.0
# KRTAP5-9 0.0
# KRT31 0.0
# RGS20 0.0
# TMCC2 0.0
# CEP70 0.0
# LZTS2 0.0
# KRT40 0.0
# SAMD3 0.0
# KRTAP10-8 0.0
# KRTAP10-3 0.0
# NOTCH2NL 0.0
# GLOD4 0.0
# GMPPB 0.0
# SLC25A33 0.0
# TANGO2 0.0
# ACSF3 0.0
# TRMU 0.0
# ACSS1 0.0
# FECH 0.0
# FTSJ2 0.0
# SDR39U1 0.0
# SLC25A39 0.0
# NUDT19 0.0
# MTG1 0.0
# TRMT2B 0.0
# PUSL1 0.0
# MARS2 0.0
# NSUN4 0.0
# ACSF2 0.0
# NARS2 0.0
# NIPSNAP3A 0.0
# FAHD2B 0.0
# TMEM70 0.0
# TRMT1L 0.0
# GFM1 0.0
# PUS1 0.0
# IBA57 0.0
# DARS2 0.0
# CTSH 0.0
# CECR5 0.0
# VWF 0.0
# RAE1 0.0
# UBA5 0.0
# RNF185 0.0
# ERLEC1 0.0
# FMNL1 0.0
# METTL23 0.0
# NKX3-1 0.0
# KDM4B 0.0
# MLLT3 0.0
# KIAA1598 0.0
# PHAX 0.0
# TPM1 0.0
# TRIM68 0.0
# BIRC2 0.0
# AK9 0.0
# CALU 0.0
# CLGN 0.0
# CTSD 0.0
# HNRNPU 0.0
# SUCLG2 0.0
# TSR1 0.0
# ZBTB8OS 0.0
# KIF20B 0.0
# UGGT1 0.0
# Mgp 0.0
# Sel1l 0.0
# Calml3 0.0
# Tuba3a 0.0
# KIT 0.0
# ompA 0.0
# LYZL2 0.0
# SMARCC2 0.0
# PCNA 0.0
# GNB2L1 0.0
# TXNDC11 0.0
# KIAA1468 0.0
# USP25 0.0
# MARS 0.0
# SRSF9 0.0
# USO1 0.0
# EBP 0.0
# C15orf39 0.0
# KLF16 0.0
# BRINP1 0.0
# STAT1 0.0
# SMYD3 0.0
# STARD13 0.0
# CHTF18 0.0
# NOS3 0.0
# GUCY1B3 0.0
# FES 0.0
# RPS3A 0.0
# DAP3 0.0
# SIM1 0.0
# PIM1 0.0
# FNIP1 0.0
# TAH1 0.0
# ERN1 0.0
# AHR 0.0
# PPARA 0.0
# GNA12 0.0
# FLT3 0.0
# GUCY1A2 0.0
# DAPK1 0.0
# SWE1 0.0
# RIPK1 0.0
# RPS3 0.0
# COPS3 0.0
# TTI2 0.0
# STK11 0.0
# FKBP4 0.0
# AIP 0.0
# VEGFA 0.0
# SMYD2 0.0
# HES1 0.0
# PI4K2B 0.0
# PI4K2A 0.0
# RARRES3 0.0
# CDK5R1 0.0
# MAP3K3 0.0
# MYOCD 0.0
# FBXW8 0.0
# TOM70 0.0
# MAP3K7 0.0
# Nos1 0.0
# EIF2AK1 0.0
# SVIL 0.0
# CALM1 0.0
# FKBPL 0.0
# BCL2 0.0
# ATR 0.0
# REV1 0.0
# Dnajc7 0.0
# Stub1 0.0
# Crnkl1 0.0
# PPIL2 0.0
# LCK 0.0
# FYN 0.0
# FKBP8 0.0
# SLC2A4 0.0
# ALG2 0.0
# RCAN1 0.0
# PTGES3 0.0
# RNF114 0.0
# PINK1 0.0
# POLH 0.0
# TNK2 0.0
# NLRP3 0.0
# NLRP2 0.0
# NOD1 0.0
# NLRP4 0.0
# MIF 0.0
# STRADA 0.0
# PIWIL2 0.0
# STK36 0.0
# GSK3B 0.0
# CSNK1A1 0.0
# GRK6 0.0
# MID1 0.0
# MET 0.0
# HDAC8 0.0
# BRMS1 0.0
# DSN1 0.0
# BLM 0.0
# NUDC 0.0
# PAFAH1B1 0.0
# NUDCD2 0.0
# ACVRL1 0.0
# STK33 0.0
# TYMP 0.0
# IP6K2 0.0
# MTRNR2L1 0.0
# IRF3 0.0
# PACRG 0.0
# HSP90AB3P 0.0
# HSP90AA5P 0.0
# HSP90AB2P 0.0
# WASL 0.0
# CFLAR 0.0
# CHEK1 0.0
# AMHR2 0.0
# ICK 0.0
# PSKH1 0.0
# MAP3K8 0.0
# DDR2 0.0
# GSK3A 0.0
# TSSK2 0.0
# ROR2 0.0
# MAP3K9 0.0
# EPHA2 0.0
# AKT2 0.0
# FGR 0.0
# TOMM70A 0.0
# TBK1 0.0
# IFIT1 0.0
# AGO1 0.0
# METTL18 0.0
# ILF3 0.0
# US3 0.0
# FAM162A 0.0
# MAP3K11 0.0
# AXL 0.0
# IRF1 0.0
# PIK3C3 0.0
# RBCK1 0.0
# TOMM40 0.0
# PGR 0.0
# LSM1 0.0
# CERS2 0.0
# Nr3c1 0.0
# KATNA1 0.0
# KEAP1 0.0
# CKS2 0.0
# CKS1B 0.0
# Stk11 0.0
# GZMA 0.0
# MGEA5 0.0
# PPP6R3 0.0
# RHOBTB2 0.0
# USP19 0.0
# PRKACA 0.0
# ADRBK1 0.0
# RPS6KA1 0.0
# CHORDC1 0.0
# FKBP6 0.0
# TTC4 0.0
# UNC45B 0.0
# CEP57 0.0
# CEP76 0.0
# CDK1 0.0
# PTGDS 0.0
# PTGDR 0.0
# TRAF3IP2 0.0
# WDR76 0.0
# AGO3 0.0
# PSKH2 0.0
# MYLK4 0.0
# CDKL2 0.0
# CDKL4 0.0
# AURKC 0.0
# CDK15 0.0
# CDK18 0.0
# CDK7 0.0
# CDK13 0.0
# NES 0.0
# Cdc37 0.0
# Myo1c 0.0
# Lrr1 0.0
# RHOBTB3 0.0
# EGLN1 0.0
# UNC45A 0.0
# RPAP3 0.0
# TTK 0.0
# EIF2S1 0.0
# CRBN 0.0
# UHRF1 0.0
# FLCN 0.0
# FNIP2 0.0
# AKT3 0.0
# CDK11A 0.0
# STK35 0.0
# GBP2 0.0
# ANKMY2 0.0
# PDIK1L 0.0
# BTK 0.0
# RALBP1 0.0
# ARNTL 0.0
# NPAS2 0.0
# SRC 0.0
# AHSA2 0.0
# TJP1 0.0
# RPS6 0.0
# BECN1 0.0
# SKP1 0.0
# CHUK 0.0
# MAP3K14 0.0
# HIF3A 0.0
# Ppard 0.0
# Pparg 0.0
# Ppara 0.0
# PPARD 0.0
# HOPX 0.0
# PMF1 0.0
# MIS12 0.0
# Tgfbr2 0.0
# NCL 0.0
# RPL17 0.0
# RPL32 0.0
# RPL5 0.0
# RPS16 0.0
# TXNDC5 0.0
# RPS20 0.0
# MARCKS 0.0
# RPL3 0.0
# SUPT5H 0.0
# RPL23A 0.0
# RPL29 0.0
# MYLK2 0.0
# TTC9C 0.0
# PLCE1 0.0
# EFTUD2 0.0
# CNOT6 0.0
# PRPF8 0.0
# FLII 0.0
# CALD1 0.0
# NUDCD3 0.0
# FAM83H 0.0
# CACYBP 0.0
# CEP97 0.0
# DYNC1H1 0.0
# SCRIB 0.0
# TOMM34 0.0
# SNRNP200 0.0
# PIH1D1 0.0
# URI1 0.0
# MLF2 0.0
# YTHDC2 0.0
# HSPA7 0.0
# HSPA1L 0.0
# TCP1 0.0
# MDH1 0.0
# PSAT1 0.0
# FASN 0.0
# FLNA 0.0
# NUMA1 0.0
# UBA1 0.0
# PSMD1 0.0
# AARS 0.0
# EIF3H 0.0
# IARS2 0.0
# RPSA 0.0
# EIF2AK2 0.0
# FER 0.0
# PKN2 0.0
# MAST2 0.0
# MERTK 0.0
# DYRK4 0.0
# TIE1 0.0
# NPRL2 0.0
# TESK2 0.0
# MAP3K6 0.0
# EPHB6 0.0
# CSF1R 0.0
# MAP3K12 0.0
# EPHB1 0.0
# ACVR1C 0.0
# FASTK 0.0
# KSR2 0.0
# BMPR1A 0.0
# FRK 0.0
# PRKY 0.0
# MOS 0.0
# MAP3K15 0.0
# MYO3B 0.0
# SGK2 0.0
# INSRR 0.0
# ALPK1 0.0
# GRK4 0.0
# TNNI3K 0.0
# FGFR1 0.0
# MATK 0.0
# ITK 0.0
# NTRK3 0.0
# FLT4 0.0
# ACVR1B 0.0
# DCLK2 0.0
# NTRK2 0.0
# MAP4K4 0.0
# ACVR2B 0.0
# SGK3 0.0
# CAMKK1 0.0
# NEK11 0.0
# KSR1 0.0
# PRKCB 0.0
# WNK4 0.0
# SRPK1 0.0
# STYK1 0.0
# HCK 0.0
# PRKG2 0.0
# MAP2K7 0.0
# MAPK15 0.0
# PRKX 0.0
# JAK1 0.0
# TP53RK 0.0
# FBXW2 0.0
# FBXO38 0.0
# TRIM56 0.0
# KLHL38 0.0
# FBXO24 0.0
# FBXL3 0.0
# WSB2 0.0
# FBXL2 0.0
# FBXL12 0.0
# KLHL6 0.0
# ENC1 0.0
# KCTD8 0.0
# KLHL25 0.0
# FBXL14 0.0
# FBXW7 0.0
# FBXO9 0.0
# KLHL22 0.0
# PRPF19 0.0
# KLHL26 0.0
# RAPSN 0.0
# FBXO18 0.0
# FBXL15 0.0
# FBXL8 0.0
# TRIM17 0.0
# FBXL18 0.0
# RNF19B 0.0
# RNF10 0.0
# ARMC5 0.0
# KLHL14 0.0
# FBXO28 0.0
# FBXO27 0.0
# FBXL13 0.0
# NHLRC1 0.0
# SF3B3 0.0
# KBTBD7 0.0
# FBXO3 0.0
# RAB40A 0.0
# ANAPC2 0.0
# AREL1 0.0
# KLHL15 0.0
# WWP1 0.0
# PCGF1 0.0
# HECTD3 0.0
# TRIM49 0.0
# KLHL1 0.0
# TRIM10 0.0
# KLHL23 0.0
# TRIM2 0.0
# ZBTB20 0.0
# KLHL29 0.0
# KLHL32 0.0
# SH3RF2 0.0
# ASB3 0.0
# KLHL13 0.0
# PCGF3 0.0
# HERC6 0.0
# RHOBTB1 0.0
# FBXO40 0.0
# FBXW5 0.0
# KCNG1 0.0
# SPSB3 0.0
# TRIM36 0.0
# DTX4 0.0
# ASB6 0.0
# ZBTB49 0.0
# MARCH9 0.0
# LRSAM1 0.0
# FBXO4 0.0
# TRIM74 0.0
# RCBTB2 0.0
# RCBTB1 0.0
# ASB17 0.0
# PCGF6 0.0
# KCNS3 0.0
# TRIM73 0.0
# SPSB1 0.0
# KCNA6 0.0
# SOCS6 0.0
# HERC4 0.0
# TRIM41 0.0
# TRIM7 0.0
# G2E3 0.0
# RNF111 0.0
# RNF40 0.0
# FBXO34 0.0
# FBXO10 0.0
# TRIM37 0.0
# RGS11 0.0
# RGS6 0.0
# PREB 0.0
# ZBED4 0.0
# RAG1 0.0
# ZC3H7B 0.0
# FOXD4L6 0.0
# NR3C2 0.0
# POGK 0.0
# NR1H3 0.0
# RGS7 0.0
# STAT2 0.0
# NR2C2 0.0
# GTF2IRD2 0.0
# DLX6 0.0
# NR1I3 0.0
# HP1BP3 0.0
# SREBF1 0.0
# NFRKB 0.0
# KAT5 0.0
# IRF2 0.0
# TFDP3 0.0
# TEAD2 0.0
# C20orf194 0.0
# LARP4B 0.0
# ZNF74 0.0
# SIM2 0.0
# NR1I2 0.0
# TBX22 0.0
# CXXC1 0.0
# DMRTA1 0.0
# SETDB1 0.0
# NFIC 0.0
# SLFN11 0.0
# ZNF215 0.0
# TCF25 0.0
# ISX 0.0
# TADA2A 0.0
# ATF3 0.0
# CEBPE 0.0
# FOXP2 0.0
# MKX 0.0
# MAX 0.0
# FOXM1 0.0
# MAFG 0.0
# TSSK3 0.0
# YES1 0.0
# SGK223 0.0
# IRAK2 0.0
# NEK8 0.0
# CAMK2G 0.0
# DYRK1B 0.0
# PDGFRB 0.0
# PRKCQ 0.0
# TYRO3 0.0
# RPS6KL1 0.0
# PKN1 0.0
# DDR1 0.0
# GRK7 0.0
# EPHA1 0.0
# PRKCG 0.0
# SRPK3 0.0
# PIM3 0.0
# TESK1 0.0
# NUAK2 0.0
# PRKCH 0.0
# MAP4K1 0.0
# MYLK3 0.0
# RET 0.0
# CDK6 0.0
# RPS6KB1 0.0
# RPS6KC1 0.0
# PRKAA2 0.0
# RPS6KA2 0.0
# STK38L 0.0
# RPS6KA6 0.0
# EPHA4 0.0
# IRAK3 0.0
# DMPK 0.0
# CAMKV 0.0
# CAMK1G 0.0
# PIM2 0.0
# BMX 0.0
# STK32B 0.0
# IGF1R 0.0
# TAOK3 0.0
# PTK6 0.0
# ERBB4 0.0
# PASK 0.0
# CDK14 0.0
# MUSK 0.0
# PTK2 0.0
# STK32C 0.0
# MAP4K2 0.0
# PTK2B 0.0
# MINK1 0.0
# DAPK3 0.0
# CAMKK2 0.0
# CAMK4 0.0
# PRKD2 0.0
# CAMK2A 0.0
# CAMK2B 0.0
# CAMK2D 0.0
# CLK2 0.0
# GIGYF2 0.0
# TUBB2B 0.0
# PDRG1 0.0
# TUBAL3 0.0
# MMP2 0.0
# SSR4 0.0
# VARS 0.0
# PRPF4B 0.0
# COBLL1 0.0
# SKIV2L2 0.0
# ZMYM1 0.0
# FAM103A1 0.0
# WDR20 0.0
# WEE1 0.0
# LLGL1 0.0
# FZR1 0.0
# MAGEA4 0.0
# HLA-A 0.0
# ARNT2 0.0
# TRIM69 0.0
# WBP2 0.0
# UQCRB 0.0
# TEKT4 0.0
# TK1 0.0
# AMOTL2 0.0
# BEX2 0.0
# TIGD5 0.0
# AMOT 0.0
# PPP1R13L 0.0
# MAGEB16 0.0
# MAGEA9B 0.0
# MAGEA10 0.0
# MDM1 0.0
# FXR1 0.0
# AMOTL1 0.0
# RAD18 0.0
# TSPYL4 0.0
# RPL7L1 0.0
# DCAF6 0.0
# TSPYL1 0.0
# CCDC85B 0.0
# ASCC2 0.0
# NDUFA2 0.0
# ARPC1A 0.0
# gag 0.0
# GSS 0.0
# RAP1GDS1 0.0
# ZNF346 0.0
# GNL3L 0.0
# WWP2 0.0
# PRPF3 0.0
# PRPF4 0.0
# PPIH 0.0
# ACAT2 0.0
# TXNRD1 0.0
# PRPF31 0.0
# ALYREF 0.0
# LSM4 0.0
# LSM8 0.0
# RPL26L1 0.0
# SART3 0.0
# MCC 0.0
# DMWD 0.0
# WIPI2 0.0
# TINF2 0.0
# ACD 0.0
# PFKL 0.0
# PFKM 0.0
# PFKP 0.0
# CD81 0.0
# ARHGDIA 0.0
# CDA 0.0
# COMMD4 0.0
# ELAC2 0.0
# METTL13 0.0
# RSU1 0.0
# UBA6 0.0
# Mad2l1 0.0
# EID1 0.0
# RNF126 0.0
# Ostm1 0.0
# NELL1 0.0
# IFT122 0.0
# WDR19 0.0
# CRYZ 0.0
# PPIB 0.0
# VAT1 0.0
# ALDH16A1 0.0
# ARHGAP1 0.0
# CCDC22 0.0
# MCFD2 0.0
# MCMBP 0.0
# NMD3 0.0
# NPEPL1 0.0
# OXSR1 0.0
# PLCG1 0.0
# PSMG1 0.0
# PTPN6 0.0
# SAMD9 0.0
# TXLNA 0.0
# Mlxipl 0.0
# REM1 0.0
# TSC1 0.0
# TSC2 0.0
# VIM 0.0
# FOXO1 0.0
# HMGN1 0.0
# GP1BA 0.0
# GP1BB 0.0
# CSF2RB 0.0
# SYN2 0.0
# CDC25B 0.0
# LYST 0.0
# TPH1 0.0
# UCP2 0.0
# UCP3 0.0
# CDK16 0.0
# Usp8 0.0
# HRR25 0.0
# MEPCE 0.0
# HDAC7 0.0
# MAP3K4 0.0
# MEF2C 0.0
# EXO1 0.0
# CHAF1A 0.0
# UCHL5 0.0
# DISC1 0.0
# OPTN 0.0
# GABARAPL2 0.0
# SH3GL1 0.0
# SNX24 0.0
# KAT8 0.0
# HIST1H3A 0.0
# PTPN14 0.0
# MARK3 0.0
# MEX3B 0.0
# ARHGEF2 0.0
# PPP1R14A 0.0
# ECT2 0.0
# MDC1 0.0
# TP53BP1 0.0
# HNF1A 0.0
# ITGB2 0.0
# gag-pol 0.0
# CBX4 0.0
# SQSTM1 0.0
# HDAC4 0.0
# BAD 0.0
# EFNB3 0.0
# SSFA2 0.0
# PRDX2 0.0
# KLF11 0.0
# SORBS2 0.0
# PIAS1 0.0
# RPRD1A 0.0
# SSX2IP 0.0
# Wwtr1 0.0
# Yap1 0.0
# TBXA2R 0.0
# RASSF2 0.0
# SAV1 0.0
# CAPNS1 0.0
# EIF5 0.0
# ERP44 0.0
# FERMT2 0.0
# G6PD 0.0
# GINS4 0.0
# ISOC1 0.0
# SLC9A3R1 0.0
# UBE2V1 0.0
# SIK3 0.0
# SIK2 0.0
# DTL 0.0
# ENO1 0.0
# SHMT2 0.0
# FAM65B 0.0
# MAST1 0.0
# AKT1S1 0.0
# MTOR 0.0
# KIAA0930 0.0
# CDCA7 0.0
# SFN 0.0
# NKD2 0.0
# TESPA1 0.0
# STAC 0.0
# FAM189A2 0.0
# DMTN 0.0
# EIF4B 0.0
# NCAPD3 0.0
# SLK 0.0
# YWHAH 0.0
# LCA5 0.0
# Cenpe 0.0
# CRY1 0.0
# TBC1D4 0.0
# ATG9A 0.0
# MAPKAPK2 0.0
# PPM1H 0.0
# PTPN3 0.0
# PTPN4 0.0
# CDC25A 0.0
# MTMR4 0.0
# SMTNL2 0.0
# CGN 0.0
# SPATA13 0.0
# SAMD4A 0.0
# PLEKHG5 0.0
# PRICKLE3 0.0
# RIN1 0.0
# TFEB 0.0
# PAK7 0.0
# REEP1 0.0
# FAM163A 0.0
# CRTC2 0.0
# RAB11FIP1 0.0
# RALGPS2 0.0
# FAM53C 0.0
# ABLIM1 0.0
# EPB41L2 0.0
# SSH1 0.0
# ANKRD55 0.0
# SAMD4B 0.0
# ZNF397 0.0
# TEX33 0.0
# PTPDC1 0.0
# GJA1 0.0
# KIF5B 0.0
# EPB41L3 0.0
# USP8 0.0
# DFFA 0.0
# KLC1 0.0
# TJP2 0.0
# NOLC1 0.0
# RAI14 0.0
# EDC3 0.0
# KLC4 0.0
# NADK 0.0
# RPL31 0.0
# NCKAP1 0.0
# HNRNPL 0.0
# PABPC4 0.0
# LARP1 0.0
# SF3B1 0.0
# RRAD 0.0
# AANAT 0.0
# FOXO3 0.0
# IL9R 0.0
# INPP5A 0.0
# RGS3 0.0
# NFATC4 0.0
# HIVEP2 0.0
# LCP2 0.0
# LRMP 0.0
# TNS1 0.0
# MADD 0.0
# EIF3A 0.0
# HDAC9 0.0
# KIAA0232 0.0
# MPHOSPH9 0.0
# SYNPO 0.0
# RAP1GAP2 0.0
# NEDD4L 0.0
# WWTR1 0.0
# FHOD1 0.0
# FAM13B 0.0
# MSL2 0.0
# ZNF839 0.0
# CENPJ 0.0
# RASAL3 0.0
# WNK2 0.0
# CGNL1 0.0
# SIMC1 0.0
# ING1 0.0
# SAMSN1 0.0
# SIK1 0.0
# TRIM21 0.0
# TUBA3C 0.0
# ADORA3 0.0
# SNRPD2P1 0.0
# PARD6A 0.0
# MARK2 0.0
# DCAF7 0.0
# PNMA2 0.0
# KIF23 0.0
# MARK1 0.0
# CYFIP1 0.0
# PNMA1 0.0
# DOCK7 0.0
# CYFIP2 0.0
# HIST1H4A 0.0
# TCEB3 0.0
# BRD4 0.0
# PSMA5 0.0
# ZHX2 0.0
# AJUBA 0.0
# POTEKP 0.0
# ZAK 0.0
# PAK2 0.0
# PFAS 0.0
# VCL 0.0
# YWHAG 0.0
# ZFYVE19 0.0
# DDIT4 0.0
# PCNT 0.0
# PRCC 0.0
# TP53BP2 0.0
# SMC1A 0.0
# AP3B1 0.0
# PRPF18 0.0
# IRS2 0.0
# SNRNP40 0.0
# CWC27 0.0
# SRSF8 0.0
# B4GALT7 0.0
# RAB11FIP2 0.0
# UHRF1BP1L 0.0
# MYCBP2 0.0
# NBEAL2 0.0
# PHF3 0.0
# TIMM13 0.0
# SEC61A1 0.0
# SDF4 0.0
# RBM27 0.0
# BDP1 0.0
# KLHL7 0.0
# RBM26 0.0
# COPS7B 0.0
# PCGF5 0.0
# SPIRE2 0.0
# SPRYD3 0.0
# HS6ST2 0.0
# WDR62 0.0
# CCDC84 0.0
# PPFIBP1 0.0
# KIF11 0.0
# CEP131 0.0
# PCM1 0.0
# SARM1 0.0
# ATP6V1F 0.0
# MCM7 0.0
# EZH2 0.0
# SCNN1A 0.0
# C1orf123 0.0
# DNAJB5 0.0
# NAPA 0.0
# OFD1 0.0
# CNTRL 0.0
# FBF1 0.0
# NPHP1 0.0
# DCTN1 0.0
# SGTB 0.0
# Tpm4 0.0
# POLR1C 0.0
# NUP37 0.0
# ARMCX3 0.0
# BIN1 0.0
# KIF13A 0.0
# MSH6 0.0
# XRCC5 0.0
# ETF1 0.0
# HK1 0.0
# NUP205 0.0
# ALOX5 0.0
# TRAP1 0.0
# EXT1 0.0
# TGFBRAP1 0.0
# SMAD4 0.0
# UVRAG 0.0
# RYK 0.0
# PSMC4 0.0
# ESX1 0.0
# OGFR 0.0
# USP7 0.0
# CEP72 0.0
# NRBF2 0.0
# VPS11 0.0
# DND1 0.0
# ACVR1 0.0
# AK2 0.0
# CFL1 0.0
# HSDL2 0.0
# PCMT1 0.0
# RPE 0.0
# UFM1 0.0
# VPS16 0.0
# CRKL 0.0
# MKNK2 0.0
# KIF2A 0.0
# DNAJC11 0.0
# Vps41 0.0
# Ppp6r1 0.0
# VPS8 0.0
# VPS33A 0.0
# ISOC2 0.0
# C15orf27 0.0
# ARFGAP1 0.0
# C7orf60 0.0
# CROCC 0.0
# PA2G4 0.0
# SND1 0.0
# ANXA5 0.0
# SNRPB2 0.0
# EIF5B 0.0
# GPI 0.0
# IDH2 0.0
# MRPL12 0.0
# CRNN 0.0
# ZNF207 0.0
# CPNE3 0.0
# CS 0.0
# CPSF6 0.0
# SRP68 0.0
# MYL12B 0.0
# CBS 0.0
# WDHD1 0.0
# HSP90B2P 0.0
# EIF4A1 0.0
# EEF1G 0.0
# RPS19 0.0
# RPL7A 0.0
# EIF2AK4 0.0
# COQ3 0.0
# GLRX 0.0
# LTA4H 0.0
# PRDX5 0.0
# PLS3 0.0

# %% [markdown]
# Degree Trimming

# %% [markdown]
# Trimming with the degree higher than 6

# %%
# remove nodes with the degree lower than 6
outdeg = nx.degree(U)
to_remove = [n for n in outdeg if outdeg[n] <= 6]
#create a new variable
U_degree6=U.remove_nodes_from(to_remove)
# keep nodes with the degree higher than 6 ( looks similar like the trim network)
to_keep = [n for n in outdeg if outdeg[n] > 6]
U_degree6=U.subgraph(to_keep)

# %%
#X odes of degree > 6 and all organismus is the same
nx.draw(U_degree6,with_labels=True,font_size=6)
plt.show()

# %%
# count nb of nodes when degree higher than 6
nx.number_of_nodes(U_degree6)
# Out:
# 41

# %%
# what are its nodes
nx.nodes(U_degree6)
# Out:
# ['NP_004574',
#  'CDK2',
#  'FN1',
#  'VCAM1',
#  'ITGA4',
#  'STAU1',
#  'NXF1',
#  'CUL7',
#  'CCDC8',
#  'NTRK1',
#  'CDC73',
#  'DLST',
#  'APP',
#  'VDAC1',
#  'EAW53700',
#  'CAG46507',
#  'HDAC5',
#  'CUL3',
#  'FBXO6',
#  'HUWE1',
#  'FUS',
#  'VCP',
#  'U2AF2',
#  'EAW98517',
#  'CDH1',
#  'NP_006588',
#  'CDC5L',
#  'EGFR',
#  'MCM2',
#  'SNW1',
#  'ABB01006',
#  'CAI64497',
#  'NP_005339',
#  'P43358',
#  'NP_037473',
#  'EAW86495',
#  'AAH51814',
#  'NP_001737',
#  'AAW67757',
#  'NP_006380',
#  'BAD93042']

# %%
# count nb of edges when degree higher than 6
nx.number_of_edges(U_degree6)
# Out:
# 213

# %%
# sort for the higest degree
a3=nx.degree(U_degree6)
a3_sorted= sorted(a3,key=a3.get, reverse=True)

for r in a3_sorted:
     print(r,a3[r])
# Out:
# AAH51814 23
# ABB01006 22
# NP_005339 19
# NP_006588 18
# CAI64497 18
# CAG46507 16
# NTRK1 14
# NP_001737 14
# AAW67757 14
# BAD93042 14
# NP_004574 13
# EAW98517 13
# EAW86495 13
# CUL7 12
# FBXO6 11
# FN1 10
# CUL3 10
# CDK2 9
# CDC73 9
# HDAC5 9
# VCP 9
# U2AF2 9
# STAU1 8
# CCDC8 8
# APP 8
# HUWE1 8
# FUS 8
# EGFR 8
# NP_006380 8
# VCAM1 7
# ITGA4 7
# NXF1 7
# DLST 7
# VDAC1 7
# CDH1 7
# CDC5L 7
# MCM2 7
# SNW1 7
# NP_037473 6
# EAW53700 1
# P43358 1

# %%
# sort for the higest betweenness centrality
a4=nx.betweenness_centrality(U_degree6)
a4_sorted= sorted(a4,key=a4.get, reverse=True)

for r in a4_sorted:
     print(r,a4[r])
# Out:
# AAH51814 0.11299463816154798
# APP 0.10303945331927615
# ABB01006 0.0990768748985868
# NP_005339 0.07322912053519388
# NP_006588 0.06563548596772667
# CAI64497 0.05256929224662083
# BAD93042 0.04391775677110075
# NTRK1 0.042680309094634494
# NP_004574 0.039609342253795914
# CAG46507 0.037848739669306214
# CUL7 0.032294558147666026
# EAW86495 0.027058883775762738
# NP_001737 0.02695035983414596
# AAW67757 0.02695035983414596
# EAW98517 0.02471096283242774
# FBXO6 0.020858946423750118
# FN1 0.020074604685913797
# CUL3 0.01435049620672139
# CDK2 0.013976639037416022
# CDC73 0.012223867111171538
# HUWE1 0.01209912403169302
# HDAC5 0.011614751489737974
# EGFR 0.011164213287452453
# U2AF2 0.011033972313942179
# VCP 0.010743798315342447
# CCDC8 0.010044264108799536
# SNW1 0.009536874683588867
# STAU1 0.009479991889552222
# NP_006380 0.009442749314049042
# CDH1 0.009310584292931951
# NXF1 0.009081398144789405
# DLST 0.008570802118538643
# FUS 0.008274745781898858
# MCM2 0.00778380994781484
# ITGA4 0.007037872709938229
# VDAC1 0.0067541015404464074
# VCAM1 0.006128333312702687
# CDC5L 0.0059450521068448526
# NP_037473 0.0048772287773843626
# EAW53700 0.0
# P43358 0.0

# %%
# visualizing betweeness and centrality in a graph
plt.figure()

degree_nodes=nx.degree(U_degree6)
centrality_nodes=nx.betweenness_centrality(U_degree6)
x0=list(degree_nodes.keys())
z0=list(centrality_nodes.values())
y0=list(degree_nodes.values())
y0_sort = sorted(y0, key=int, reverse=False)
fig, ax = plt.subplots(figsize=(30, 15)) 
        
ax.plot(x0,y0_sort, c='b')
ax1=ax.twinx()
 
ax1.plot(x0,z0, c='r')
red_patch = mpatches.Patch(color='blue', label='betweeness centrality')
blue_patch = mpatches.Patch(color='red', label='degree')
plt.legend(handles=[red_patch, blue_patch])
plt.show()

# %% [markdown]
# Find Minimum spanning tree

# %%
#print(networkx.__version__)
X= nx.to_numpy_matrix(U_whole)
mst = minimum_spanning_tree(X)
mst_new= nx.from_scipy_sparse_matrix(mst)
mst_edges= nx.generate_edgelist(mst_new)
temp_tup=tuple(nx.nodes(U_whole))
temp_U = nx.parse_edgelist(mst_edges)
Z=nx.Graph()
Z.add_node(temp_tup)
edges = nx.edges(temp_U)
Z.add_edges_from(edges)

#print(list(mst_edges))
plt.axis('off')
nx.draw(Z, node_size=4)
plt.show()

# %% [markdown]
# 1a. In a degree trimmed network look for one identifier

# %%
# response to stress in the degree trimmed network color in blue
color_map = []
for node in U_degree6:
    if node == "NP_005339":
        color_map.append('blue')# response to stress
    elif node == "BAD93042":
        color_map.append('blue')
    elif node == "CAI64497":
        color_map.append('blue')
    else: color_map.append('red') # others    
nx.draw(U_degree6,node_color = color_map,with_labels = True)
plt.show()

# %% [markdown]
# Shortest path analysis among these three proteins with response to stress identifier

# %%
# shortest path between two nodes with response to stress
nodes= nx.nodes(U_degree6)
nx.shortest_path(U_degree6,source='BAD93042',target="NP_005339")
# Out:
# ['BAD93042', 'HDAC5', 'NP_005339']

# %%
# shortest path between two nodes with response to stress
nodes= nx.nodes(U_degree6)
nx.shortest_path(U,source='BAD93042',target="CAI64497")

# %%
# shortest path between two nodes with response to stress
nodes= nx.nodes(U)
nx.shortest_path(U,source='NP_005339',target="CAI64497")

# %% [markdown]
# Finding the meaning

# %% [markdown]
# 1b. Creating subgraphs

# %%
# upload the geoterm identifier per protein
df = pd.read_excel('functions_data.xls', sheetname='knowledge_data-2')

# %%
# create a dataframe per selected fature and indentifier
df_identifier=pd.DataFrame(df.groupby('protein')['identifier'].apply(list))
df_feature=pd.DataFrame(df.groupby('protein')['feature'].apply(list))
df_concat=pd.concat([df_identifier,df_feature],axis=1)

# %%
# create a dictionary 
path_dic_identifier = {}
for index, row in df_identifier.iterrows():
    path_dic_identifier[index] = row['identifier']

# %%
# for the library
all_functions=list(df.identifier.unique())

# %%
# missing values (remove them)
dic_list=list(path_dic_identifier.keys())
len(path_dic_identifier.keys())
remove_U=list(set(nx.nodes(U_degree6))-set(path_dic_identifier.keys()))
remove_D=list(set(path_dic_identifier.keys())-set(nx.nodes(U_degree6)))
keep = list(set(nx.nodes(U_degree6)).intersection(set(path_dic_identifier.keys())))

# %%
for i in remove_U:
    U_degree6.remove_node(i)

# %%
for i in remove_D:
    del path_dic_identifier[i]

# %%
# for the library
importlib.reload(nf)

# for the library
all_functions=list(df.identifier.unique())

#attribute_1= str(input('Please enter the first identifier: '))
#attribute_2= str(input('Please enter the second identifier: '))

def select(all_identifiers):

    master = Tk()

    variable = StringVar(master)
    variable.set(all_functions[0]) # default value

    w = OptionMenu(master, variable, *all_functions)
    w.pack()
    
    return("value is:" + variable.get())

    mainloop()

# %% [markdown]
# Meaning in the network

# %%
# two identifiers function
nf.choose_identifier('ATP binding','response to stress',path_dic_identifier,U_degree6)
# Out:
# degree:
#
#
# CDC5L 5
# NTRK1 5
# ABB01006 4
# CAI64497 4
# NP_005339 4
# VCP 4
# BAD93042 3
# CDC73 3
# EAW86495 2
#
#
# betweeness centrality:
#
#
# CDC5L 0.181547619047619
# NTRK1 0.181547619047619
# ABB01006 0.09345238095238093
# CAI64497 0.09345238095238093
# NP_005339 0.09345238095238093
# VCP 0.0744047619047619
# BAD93042 0.033928571428571426
# CDC73 0.026785714285714284
# EAW86495 0.007142857142857143
#
#
# graphical representation:

# %%
# select one indentifier in the MST
nf.choose_identifier_MST('response to stress',path_dic_identifier,U)
# Out:
# degree of response to stress :
#
#
# NP_005339 19
# CAI64497 18
# BAD93042 14
#
#
# betweeness centrality of response to stress :
#
#
# NP_005339 0.07322912053519388
# CAI64497 0.05256929224662083
# BAD93042 0.04391775677110076
#
#
# graphical representation:

# %%
# select one identiofier in the whole function
nf.choose_identifier_whole('response to stress',path_dic_identifier,U_whole)
# Out:
# degree of response to stress :
#
#
# NP_005339 817
# CAI64497 169
# BAD93042 136
#
#
# betweeness centrality of response to stress :
#
#
# NP_005339 0.4723494667086117
# BAD93042 0.06564739196995312
# CAI64497 0.061279196271432024

# %% [markdown]
# The knowlege graph expansion

# %%
# import data
import pandas as pd
df_data= pd.read_excel('Finalised-knowledge-graph (3).xlsx')

# delete NAN
df_data1=df_data.dropna()

# create a dictionary for the knowledge expansion via set operation
dic={}
dic2={}
for i in list(df_data1.ID.unique()):
    df_per_protein= df_data1[df_data1['ID']==i] # search for specific protein
    df_grouped=pd.DataFrame(df_per_protein.groupby("Species")['function'].apply(list)) # create a group of functions per species in a dataframe
    if 'Arabidopsis thaliana' in df_grouped.index:
        set_plant=set(df_grouped['function']['Arabidopsis thaliana'])
    else:
        set_plant=set()
    
    if 'Mus musculus' in df_grouped.index:
        set_mouse=set(df_grouped['function']['Mus musculus'])
    else:
        set_mouse=set()
        
    if 'Rattus norvegicus' in df_grouped.index:
        set_rat=set(df_grouped['function']['Rattus norvegicus'])
    else:
        set_rat=set()
        
    if 'Homo Sapiens' in df_grouped.index:
        set_human=set(df_grouped['function']['Homo Sapiens'])
    else:
        set_human=set()
    
    intersection_human_rat=set_human.intersection(set_rat)
    
    intersection_human_plant=set_human.intersection(set_plant)
    
    difference_mouse=list(set_mouse.difference(set_human))
    
    difference_rat=list(set_rat.difference(set_human))
    
    difference_plant=list(set_plant.difference(set_human))
    
    dic[i] = list(set_human),difference_mouse,difference_rat,difference_plant
    dic2[i] = len(list(set_human)),len(difference_mouse),len(difference_rat),len(difference_plant)
new_df = pd.DataFrame.from_dict(dic)
new_df = new_df.transpose()
new_df.columns=['Function_Human','Function_Mouse','Function_Rat','Function_Plant']
new_df.head()

new_df2 = pd.DataFrame.from_dict(dic2)
new_df2 = new_df2.transpose()
new_df2.columns=['Function_Human','Function_Mouse','Function_Rat','Function_Plant']
new_df2
# Out:
#            Function_Human  Function_Mouse  Function_Rat  Function_Plant
# AAH51814               18               4             3               0
# AAW67757               28              61            61               0
# BAD93042               14               9             0               0
# CAI64497               39              21            33              19
# CCDC8                   4               1             0               0
# CDC5L                  34               0            12               0
# CDK2                   23              19            13              42
# CUL3                   47               0             2               0
# CUL7                   14               3             0               0
# DLST                   12              40            36               1
# EAW53700               67               3             0               0
# EAW86495               16               0             0               0
# EAW98517               15              25            26               9
# FBXO6                  13               0             3               0
# FN1                    40               1             1               0
# FUS                     7              11            10               0
# HDAC5                  40               1            35               0
# HUWE1                  18               0             1               1
# ITGA4                  27               1             8               0
# MCM2                   23               0             1               9
# NPM                    46              43            43               0
# NP_001737              15               3             3               3
# NP_005339              43              23            23               9
# NP_006380              13               0             0               0
# NP_006588              55               1             0               2
# NP_037473              12               4             0               3
# NTRK1                  71               0             1               0
# NXF1                    9               0             0               0
# P43358                  4              43            49               0
# PFKP                   16               0             0               0
# PHB                    39               9            10               0
# SNW1                   14               0            26              15
# STAU1                   8               0             1               0
# TRAP1                  14               0             0               0
# U2AF2                  17               0             3               1
# VCAM1                  29               0             4               0
# VCP                    65               0             0               6
# VDAC1                  25               0             0               2
# YWHAZ                   1              15             3               2

# %%
# heat map
sns.heatmap(new_df2, cmap="Blues")
plt.figure(figsize=(10,10))
plt.show()
